# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
allData = pd.read_csv("journal.pone.0185912.s003.csv")
allData.head()
# Out:
#                  Source Site_source         Target Site_target  Transfers  \
# 0  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          1
# 1  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 2  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 3  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          3
# 4  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
#
#    Year  Week
# 0  2014    48
# 1  2014    49
# 2  2014    50
# 3  2014    51
# 4  2015     1

# %%
np.unique(allData.Site_source)
# Out:
# array(['DH', 'Orpington', 'PRUH'], dtype=object)

# %%
allData.shape
# Out:
# (31338, 7)

# %%
allData.Transfers.sum()
# Out:
# 195257

# %%
def common_member(a, b): 
      
    a_set = set(a) 
    b_set = set(b) 
      
    # check length  
    if len(a_set.intersection(b_set)) > 0: 
        return(a_set.intersection(b_set))   
    else: 
        return("no common elements")

# %%
#Get data coming only from PRUH hospital and only in the year 2015

PRUHData = allData[allData['Site_source'] == 'PRUH']
PRUHData = PRUHData[PRUHData['Year'] == 2015]
PRUHWards = np.unique(PRUHData.Source)

#adding strings for the unique transfer name 
PRUHData['transfer'] = PRUHData.Source + PRUHData.Target
PRUHData['transfer_backwards'] = PRUHData.Target + PRUHData.Source
print(np.unique(PRUHData.transfer_backwards).shape,np.unique(PRUHData.transfer).shape)

#finding the list of transfers that exist in both directions
twoWayTransfers = np.intersect1d(np.unique(PRUHData.transfer_backwards),np.unique(PRUHData.transfer))
print(twoWayTransfers.shape, twoWayTransfers)

PRUHAllTransfers = np.unique(PRUHData.transfer)

common1 = PRUHData[PRUHData['transfer'] == 'CoronaryCareUnit.PRUH.AcuteMedicalUnit.EAU']
twoWayTransfers.shape

PRUHData['transfer_final'] = PRUHData.Source + PRUHData.Target
PRUHData['target_final'] = 0
PRUHData['source_final'] = 0
# Out:
# (739,) (739,)
# (426,) ['AcuteMedicalUnit.EAUClinicalDecisionUnit.PRUH'
#  'AcuteMedicalUnit.EAUCoronaryCareUnit.PRUH.'
#  'AcuteMedicalUnit.EAUDischargeLounge'
#  'AcuteMedicalUnit.EAUFarnboroughWard'
#  'AcuteMedicalUnit.EAUHASU.HyperAcuteStrokeUnit.PRUH.'
#  'AcuteMedicalUnit.EAUMedicalWard1' 'AcuteMedicalUnit.EAUMedicalWard3'
#  'AcuteMedicalUnit.EAUMedicalWard4' 'AcuteMedicalUnit.EAUMedicalWard7'
#  'AcuteMedicalUnit.EAUMedicalWard8' 'AcuteMedicalUnit.EAUMedicalWard9'
#  'AcuteMedicalUnit.EAUPlannedInvestigationUnit'
#  'AcuteMedicalUnit.EAURecoveryWard1'
#  'AcuteMedicalUnit.EAUStrokeUnit.PRUH.'
#  'AcuteMedicalUnit.EAUSurgicalWard3.SAU.'
#  'AcuteMedicalUnit.EAUSurgicalWard4' 'AcuteMedicalUnit.EAUSurgicalWard5'
#  'AcuteMedicalUnit.EAUSurgicalWard6'
#  'AcuteMedicalUnit.EAUSurgicalWard7.Ortho.'
#  'ChartwellUnitClinicalDecisionUnit.PRUH'
#  'ChartwellUnitCoronaryCareUnit.PRUH.' 'ChartwellUnitFarnboroughWard'
#  'ChartwellUnitIntensiveCare.HighDepUnit.PRUH.'
#  'ChartwellUnitMedicalWard1' 'ChartwellUnitMedicalWard3'
#  'ChartwellUnitMedicalWard4' 'ChartwellUnitMedicalWard8'
#  'ChartwellUnitMedicalWard9' 'ChartwellUnitSurgicalWard3.SAU.'
#  'ChartwellUnitSurgicalWard5'
#  'ClinicalDecisionUnit.PRUHAcuteMedicalUnit.EAU'
#  'ClinicalDecisionUnit.PRUHChartwellUnit'
#  'ClinicalDecisionUnit.PRUHCoronaryCareUnit.PRUH.'
#  'ClinicalDecisionUnit.PRUHDischargeLounge'
#  'ClinicalDecisionUnit.PRUHFarnboroughWard'
#  'ClinicalDecisionUnit.PRUHHASU.HyperAcuteStrokeUnit.PRUH.'
#  'ClinicalDecisionUnit.PRUHMedicalWard6'
#  'ClinicalDecisionUnit.PRUHMedicalWard7'
#  'ClinicalDecisionUnit.PRUHMedicalWard8'
#  'ClinicalDecisionUnit.PRUHMedicalWard9'
#  'ClinicalDecisionUnit.PRUHPlannedInvestigationUnit'
#  'ClinicalDecisionUnit.PRUHSurgicalWard3.SAU.'
#  'ClinicalDecisionUnit.PRUHSurgicalWard4'
#  'ClinicalDecisionUnit.PRUHSurgicalWard5'
#  'ClinicalDecisionUnit.PRUHSurgicalWard7.Ortho.'
#  'CoronaryCareUnit.PRUH.AcuteMedicalUnit.EAU'
#  'CoronaryCareUnit.PRUH.ChartwellUnit'
#  'CoronaryCareUnit.PRUH.ClinicalDecisionUnit.PRUH'
#  'CoronaryCareUnit.PRUH.FarnboroughWard'
#  'CoronaryCareUnit.PRUH.HASU.HyperAcuteStrokeUnit.PRUH.'
#  'CoronaryCareUnit.PRUH.IntensiveCare.HighDepUnit.PRUH.'
#  'CoronaryCareUnit.PRUH.MedicalWard1' 'CoronaryCareUnit.PRUH.MedicalWard2'
#  'CoronaryCareUnit.PRUH.MedicalWard3' 'CoronaryCareUnit.PRUH.MedicalWard6'
#  'CoronaryCareUnit.PRUH.MedicalWard7' 'CoronaryCareUnit.PRUH.MedicalWard8'
#  'CoronaryCareUnit.PRUH.MedicalWard9'
#  'CoronaryCareUnit.PRUH.PlannedInvestigationUnit'
#  'CoronaryCareUnit.PRUH.SurgicalWard2.Darwin2.'
#  'CoronaryCareUnit.PRUH.SurgicalWard3.SAU.'
#  'CoronaryCareUnit.PRUH.SurgicalWard4'
#  'CoronaryCareUnit.PRUH.SurgicalWard5'
#  'CoronaryCareUnit.PRUH.SurgicalWard6'
#  'CoronaryCareUnit.PRUH.SurgicalWard7.Ortho.'
#  'DischargeLoungeAcuteMedicalUnit.EAU'
#  'DischargeLoungeClinicalDecisionUnit.PRUH' 'DischargeLoungeMedicalWard4'
#  'DischargeLoungeMedicalWard7' 'DischargeLoungeMedicalWard9'
#  'DischargeLoungePlannedInvestigationUnit'
#  'FarnboroughDayWardRecoveryWard1' 'FarnboroughWardAcuteMedicalUnit.EAU'
#  'FarnboroughWardChartwellUnit' 'FarnboroughWardClinicalDecisionUnit.PRUH'
#  'FarnboroughWardCoronaryCareUnit.PRUH.'
#  'FarnboroughWardHASU.HyperAcuteStrokeUnit.PRUH.'
#  'FarnboroughWardIntensiveCare.HighDepUnit.PRUH.'
#  'FarnboroughWardMedicalWard1' 'FarnboroughWardMedicalWard2'
#  'FarnboroughWardMedicalWard3' 'FarnboroughWardMedicalWard4'
#  'FarnboroughWardMedicalWard6' 'FarnboroughWardMedicalWard7'
#  'FarnboroughWardMedicalWard8' 'FarnboroughWardMedicalWard9'
#  'FarnboroughWardPlannedInvestigationUnit' 'FarnboroughWardRecoveryWard1'
#  'FarnboroughWardStrokeUnit.PRUH.' 'FarnboroughWardSurgicalWard1.Darwin1.'
#  'FarnboroughWardSurgicalWard2.Darwin2.'
#  'FarnboroughWardSurgicalWard3.SAU.' 'FarnboroughWardSurgicalWard4'
#  'FarnboroughWardSurgicalWard5' 'FarnboroughWardSurgicalWard6'
#  'FarnboroughWardSurgicalWard7.Ortho.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.AcuteMedicalUnit.EAU'
#  'HASU.HyperAcuteStrokeUnit.PRUH.ClinicalDecisionUnit.PRUH'
#  'HASU.HyperAcuteStrokeUnit.PRUH.CoronaryCareUnit.PRUH.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.FarnboroughWard'
#  'HASU.HyperAcuteStrokeUnit.PRUH.IntensiveCare.HighDepUnit.PRUH.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard1'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard2'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard3'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard4'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard6'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard7'
#  'HASU.HyperAcuteStrokeUnit.PRUH.MedicalWard8'
#  'HASU.HyperAcuteStrokeUnit.PRUH.PlannedInvestigationUnit'
#  'HASU.HyperAcuteStrokeUnit.PRUH.StrokeUnit.PRUH.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.SurgicalWard1.Darwin1.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.SurgicalWard2.Darwin2.'
#  'HASU.HyperAcuteStrokeUnit.PRUH.SurgicalWard4'
#  'HASU.HyperAcuteStrokeUnit.PRUH.SurgicalWard5'
#  'IntensiveCare.HighDepUnit.PRUH.ChartwellUnit'
#  'IntensiveCare.HighDepUnit.PRUH.CoronaryCareUnit.PRUH.'
#  'IntensiveCare.HighDepUnit.PRUH.FarnboroughWard'
#  'IntensiveCare.HighDepUnit.PRUH.HASU.HyperAcuteStrokeUnit.PRUH.'
#  'IntensiveCare.HighDepUnit.PRUH.MedicalWard1'
#  'IntensiveCare.HighDepUnit.PRUH.MedicalWard2'
#  'IntensiveCare.HighDepUnit.PRUH.MedicalWard3'
#  'IntensiveCare.HighDepUnit.PRUH.MedicalWard4'
#  'IntensiveCare.HighDepUnit.PRUH.MedicalWard6'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard1.Darwin1.'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard3.SAU.'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard4'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard5'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard6'
#  'IntensiveCare.HighDepUnit.PRUH.SurgicalWard7.Ortho.'
#  'MedicalWard1AcuteMedicalUnit.EAU' 'MedicalWard1ChartwellUnit'
#  'MedicalWard1CoronaryCareUnit.PRUH.' 'MedicalWard1FarnboroughWard'
#  'MedicalWard1HASU.HyperAcuteStrokeUnit.PRUH.'
#  'MedicalWard1IntensiveCare.HighDepUnit.PRUH.' 'MedicalWard1MedicalWard2'
#  'MedicalWard1MedicalWard3' 'MedicalWard1MedicalWard4'
#  'MedicalWard1MedicalWard6' 'MedicalWard1MedicalWard8'
#  'MedicalWard1MedicalWard9' 'MedicalWard1PlannedInvestigationUnit'
#  'MedicalWard1SurgicalWard2.Darwin2.' 'MedicalWard1SurgicalWard3.SAU.'
#  'MedicalWard1SurgicalWard4' 'MedicalWard1SurgicalWard5'
#  'MedicalWard1SurgicalWard7.Ortho.' 'MedicalWard2CoronaryCareUnit.PRUH.'
#  'MedicalWard2FarnboroughWard'
#  'MedicalWard2HASU.HyperAcuteStrokeUnit.PRUH.'
#  'MedicalWard2IntensiveCare.HighDepUnit.PRUH.' 'MedicalWard2MedicalWard1'
#  'MedicalWard2MedicalWard3' 'MedicalWard2MedicalWard4'
#  'MedicalWard2MedicalWard6' 'MedicalWard2MedicalWard8'
#  'MedicalWard2MedicalWard9' 'MedicalWard2PlannedInvestigationUnit'
#  'MedicalWard2StrokeUnit.PRUH.' 'MedicalWard2SurgicalWard2.Darwin2.'
#  'MedicalWard2SurgicalWard5' 'MedicalWard2SurgicalWard6'
#  'MedicalWard3AcuteMedicalUnit.EAU' 'MedicalWard3ChartwellUnit'
#  'MedicalWard3CoronaryCareUnit.PRUH.' 'MedicalWard3FarnboroughWard'
#  'MedicalWard3HASU.HyperAcuteStrokeUnit.PRUH.'
#  'MedicalWard3IntensiveCare.HighDepUnit.PRUH.' 'MedicalWard3MedicalWard1'
#  'MedicalWard3MedicalWard2' 'MedicalWard3MedicalWard4'
#  'MedicalWard3MedicalWard6' 'MedicalWard3MedicalWard7'
#  'MedicalWard3MedicalWard8' 'MedicalWard3PlannedInvestigationUnit'
#  'MedicalWard3StrokeUnit.PRUH.' 'MedicalWard3SurgicalWard2.Darwin2.'
#  'MedicalWard3SurgicalWard4' 'MedicalWard3SurgicalWard5'
#  'MedicalWard3SurgicalWard6' 'MedicalWard4AcuteMedicalUnit.EAU'
#  'MedicalWard4ChartwellUnit' 'MedicalWard4DischargeLounge'
#  'MedicalWard4FarnboroughWard'
#  'MedicalWard4HASU.HyperAcuteStrokeUnit.PRUH.'
#  'MedicalWard4IntensiveCare.HighDepUnit.PRUH.' 'MedicalWard4MedicalWard1'
#  'MedicalWard4MedicalWard2' 'MedicalWard4MedicalWard3'
#  'MedicalWard4MedicalWard6' 'MedicalWard4MedicalWard7'
#  'MedicalWard4MedicalWard8' 'MedicalWard4PlannedInvestigationUnit'
#  'MedicalWard4SurgicalWard3.SAU.' 'MedicalWard4SurgicalWard4'
#  'MedicalWard4SurgicalWard5' 'MedicalWard4SurgicalWard6'
#  'MedicalWard6ClinicalDecisionUnit.PRUH'
#  'MedicalWard6CoronaryCareUnit.PRUH.' 'MedicalWard6FarnboroughWard'
#  'MedicalWard6HASU.HyperAcuteStrokeUnit.PRUH.'
#  'MedicalWard6IntensiveCare.HighDepUnit.PRUH.' 'MedicalWard6MedicalWard1'
#  'MedicalWard6MedicalWard2' 'MedicalWard6MedicalWard3'
#  'MedicalWard6MedicalWard4' 'MedicalWard6MedicalWard7'
#  'MedicalWard6MedicalWard8' 'MedicalWard6MedicalWard9'
#  'MedicalWard6PlannedInvestigationUnit' 'MedicalWard6StrokeUnit.PRUH.'
#  'MedicalWard6SurgicalWard3.SAU.' 'MedicalWard6SurgicalWard4'
#  'MedicalWard6SurgicalWard5' 'MedicalWard6SurgicalWard6'
#  'MedicalWard7AcuteMedicalUnit.EAU'
#  'MedicalWard7ClinicalDecisionUnit.PRUH'
#  'MedicalWard7CoronaryCareUnit.PRUH.' 'MedicalWard7DischargeLounge'
#  'MedicalWard7FarnboroughWard'
#  'MedicalWard7HASU.HyperAcuteStrokeUnit.PRUH.' 'MedicalWard7MedicalWard3'
#  'MedicalWard7MedicalWard4' 'MedicalWard7MedicalWard6'
#  'MedicalWard7MedicalWard8' 'MedicalWard7MedicalWard9'
#  'MedicalWard7PlannedInvestigationUnit' 'MedicalWard7SurgicalWard3.SAU.'
#  'MedicalWard7SurgicalWard4' 'MedicalWard7SurgicalWard5'
#  'MedicalWard7SurgicalWard7.Ortho.' 'MedicalWard8AcuteMedicalUnit.EAU'
#  'MedicalWard8ChartwellUnit' 'MedicalWard8ClinicalDecisionUnit.PRUH'
#  'MedicalWard8CoronaryCareUnit.PRUH.' 'MedicalWard8FarnboroughWard'
#  'MedicalWard8HASU.HyperAcuteStrokeUnit.PRUH.' 'MedicalWard8MedicalWard1'
#  'MedicalWard8MedicalWard2' 'MedicalWard8MedicalWard3'
#  'MedicalWard8MedicalWard4' 'MedicalWard8MedicalWard6'
#  'MedicalWard8MedicalWard7' 'MedicalWard8MedicalWard9'
#  'MedicalWard8SurgicalWard2.Darwin2.' 'MedicalWard8SurgicalWard3.SAU.'
#  'MedicalWard8SurgicalWard4' 'MedicalWard8SurgicalWard5'
#  'MedicalWard8SurgicalWard7.Ortho.' 'MedicalWard9AcuteMedicalUnit.EAU'
#  'MedicalWard9ChartwellUnit' 'MedicalWard9ClinicalDecisionUnit.PRUH'
#  'MedicalWard9CoronaryCareUnit.PRUH.' 'MedicalWard9DischargeLounge'
#  'MedicalWard9FarnboroughWard' 'MedicalWard9MedicalWard1'
#  'MedicalWard9MedicalWard2' 'MedicalWard9MedicalWard6'
#  'MedicalWard9MedicalWard7' 'MedicalWard9MedicalWard8'
#  'MedicalWard9PRUH.EmergencyDept' 'MedicalWard9PlannedInvestigationUnit'
#  'MedicalWard9SurgicalWard1.Darwin1.' 'MedicalWard9SurgicalWard3.SAU.'
#  'MedicalWard9SurgicalWard4' 'MedicalWard9SurgicalWard5'
#  'MedicalWard9SurgicalWard6' 'MedicalWard9SurgicalWard7.Ortho.'
#  'PRUH.EmergencyDeptMedicalWard9' 'PRUH.EmergencyDeptSurgicalWard4'
#  'PlannedInvestigationUnitAcuteMedicalUnit.EAU'
#  'PlannedInvestigationUnitClinicalDecisionUnit.PRUH'
#  'PlannedInvestigationUnitCoronaryCareUnit.PRUH.'
#  'PlannedInvestigationUnitDischargeLounge'
#  'PlannedInvestigationUnitFarnboroughWard'
#  'PlannedInvestigationUnitHASU.HyperAcuteStrokeUnit.PRUH.'
#  'PlannedInvestigationUnitMedicalWard1'
#  'PlannedInvestigationUnitMedicalWard2'
#  'PlannedInvestigationUnitMedicalWard3'
#  'PlannedInvestigationUnitMedicalWard4'
#  'PlannedInvestigationUnitMedicalWard6'
#  'PlannedInvestigationUnitMedicalWard7'
#  'PlannedInvestigationUnitMedicalWard9'
#  'PlannedInvestigationUnitRecoveryWard1'
#  'PlannedInvestigationUnitSurgicalWard1.Darwin1.'
#  'PlannedInvestigationUnitSurgicalWard3.SAU.'
#  'PlannedInvestigationUnitSurgicalWard4'
#  'PlannedInvestigationUnitSurgicalWard5'
#  'PlannedInvestigationUnitSurgicalWard6'
#  'RecoveryWard1AcuteMedicalUnit.EAU' 'RecoveryWard1FarnboroughDayWard'
#  'RecoveryWard1FarnboroughWard' 'RecoveryWard1PlannedInvestigationUnit'
#  'RecoveryWard1SurgicalWard3.SAU.' 'RecoveryWard1SurgicalWard4'
#  'RecoveryWard1SurgicalWard5' 'RecoveryWard1SurgicalWard6'
#  'RecoveryWard1SurgicalWard7.Ortho.'
#  'StrokeUnit.PRUH.AcuteMedicalUnit.EAU' 'StrokeUnit.PRUH.FarnboroughWard'
#  'StrokeUnit.PRUH.HASU.HyperAcuteStrokeUnit.PRUH.'
#  'StrokeUnit.PRUH.MedicalWard2' 'StrokeUnit.PRUH.MedicalWard3'
#  'StrokeUnit.PRUH.MedicalWard6' 'StrokeUnit.PRUH.SurgicalWard1.Darwin1.'
#  'StrokeUnit.PRUH.SurgicalWard3.SAU.' 'StrokeUnit.PRUH.SurgicalWard4'
#  'StrokeUnit.PRUH.SurgicalWard5' 'SurgicalWard1.Darwin1.FarnboroughWard'
#  'SurgicalWard1.Darwin1.HASU.HyperAcuteStrokeUnit.PRUH.'
#  'SurgicalWard1.Darwin1.IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard1.Darwin1.MedicalWard9'
#  'SurgicalWard1.Darwin1.PlannedInvestigationUnit'
#  'SurgicalWard1.Darwin1.StrokeUnit.PRUH.'
#  'SurgicalWard1.Darwin1.SurgicalWard2.Darwin2.'
#  'SurgicalWard1.Darwin1.SurgicalWard3.SAU.'
#  'SurgicalWard1.Darwin1.SurgicalWard5'
#  'SurgicalWard1.Darwin1.SurgicalWard6'
#  'SurgicalWard1.Darwin1.SurgicalWard7.Ortho.'
#  'SurgicalWard2.Darwin2.CoronaryCareUnit.PRUH.'
#  'SurgicalWard2.Darwin2.FarnboroughWard'
#  'SurgicalWard2.Darwin2.HASU.HyperAcuteStrokeUnit.PRUH.'
#  'SurgicalWard2.Darwin2.MedicalWard1' 'SurgicalWard2.Darwin2.MedicalWard2'
#  'SurgicalWard2.Darwin2.MedicalWard3' 'SurgicalWard2.Darwin2.MedicalWard8'
#  'SurgicalWard2.Darwin2.SurgicalWard1.Darwin1.'
#  'SurgicalWard2.Darwin2.SurgicalWard4'
#  'SurgicalWard2.Darwin2.SurgicalWard6'
#  'SurgicalWard3.SAU.AcuteMedicalUnit.EAU'
#  'SurgicalWard3.SAU.ChartwellUnit'
#  'SurgicalWard3.SAU.ClinicalDecisionUnit.PRUH'
#  'SurgicalWard3.SAU.CoronaryCareUnit.PRUH.'
#  'SurgicalWard3.SAU.FarnboroughWard'
#  'SurgicalWard3.SAU.IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard3.SAU.MedicalWard1' 'SurgicalWard3.SAU.MedicalWard4'
#  'SurgicalWard3.SAU.MedicalWard6' 'SurgicalWard3.SAU.MedicalWard7'
#  'SurgicalWard3.SAU.MedicalWard8' 'SurgicalWard3.SAU.MedicalWard9'
#  'SurgicalWard3.SAU.PlannedInvestigationUnit'
#  'SurgicalWard3.SAU.RecoveryWard1' 'SurgicalWard3.SAU.StrokeUnit.PRUH.'
#  'SurgicalWard3.SAU.SurgicalWard1.Darwin1.'
#  'SurgicalWard3.SAU.SurgicalWard4' 'SurgicalWard3.SAU.SurgicalWard5'
#  'SurgicalWard3.SAU.SurgicalWard6'
#  'SurgicalWard3.SAU.SurgicalWard7.Ortho.'
#  'SurgicalWard4AcuteMedicalUnit.EAU'
#  'SurgicalWard4ClinicalDecisionUnit.PRUH'
#  'SurgicalWard4CoronaryCareUnit.PRUH.' 'SurgicalWard4FarnboroughWard'
#  'SurgicalWard4HASU.HyperAcuteStrokeUnit.PRUH.'
#  'SurgicalWard4IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard4MedicalWard1' 'SurgicalWard4MedicalWard3'
#  'SurgicalWard4MedicalWard4' 'SurgicalWard4MedicalWard6'
#  'SurgicalWard4MedicalWard7' 'SurgicalWard4MedicalWard8'
#  'SurgicalWard4MedicalWard9' 'SurgicalWard4PRUH.EmergencyDept'
#  'SurgicalWard4PlannedInvestigationUnit' 'SurgicalWard4RecoveryWard1'
#  'SurgicalWard4StrokeUnit.PRUH.' 'SurgicalWard4SurgicalWard2.Darwin2.'
#  'SurgicalWard4SurgicalWard3.SAU.' 'SurgicalWard4SurgicalWard5'
#  'SurgicalWard4SurgicalWard6' 'SurgicalWard4SurgicalWard7.Ortho.'
#  'SurgicalWard5AcuteMedicalUnit.EAU' 'SurgicalWard5ChartwellUnit'
#  'SurgicalWard5ClinicalDecisionUnit.PRUH'
#  'SurgicalWard5CoronaryCareUnit.PRUH.' 'SurgicalWard5FarnboroughWard'
#  'SurgicalWard5HASU.HyperAcuteStrokeUnit.PRUH.'
#  'SurgicalWard5IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard5MedicalWard1' 'SurgicalWard5MedicalWard2'
#  'SurgicalWard5MedicalWard3' 'SurgicalWard5MedicalWard4'
#  'SurgicalWard5MedicalWard6' 'SurgicalWard5MedicalWard7'
#  'SurgicalWard5MedicalWard8' 'SurgicalWard5MedicalWard9'
#  'SurgicalWard5PlannedInvestigationUnit' 'SurgicalWard5RecoveryWard1'
#  'SurgicalWard5StrokeUnit.PRUH.' 'SurgicalWard5SurgicalWard1.Darwin1.'
#  'SurgicalWard5SurgicalWard3.SAU.' 'SurgicalWard5SurgicalWard4'
#  'SurgicalWard5SurgicalWard6' 'SurgicalWard5SurgicalWard7.Ortho.'
#  'SurgicalWard6AcuteMedicalUnit.EAU' 'SurgicalWard6CoronaryCareUnit.PRUH.'
#  'SurgicalWard6FarnboroughWard'
#  'SurgicalWard6IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard6MedicalWard2' 'SurgicalWard6MedicalWard3'
#  'SurgicalWard6MedicalWard4' 'SurgicalWard6MedicalWard6'
#  'SurgicalWard6MedicalWard9' 'SurgicalWard6PlannedInvestigationUnit'
#  'SurgicalWard6RecoveryWard1' 'SurgicalWard6SurgicalWard1.Darwin1.'
#  'SurgicalWard6SurgicalWard2.Darwin2.' 'SurgicalWard6SurgicalWard3.SAU.'
#  'SurgicalWard6SurgicalWard4' 'SurgicalWard6SurgicalWard5'
#  'SurgicalWard6SurgicalWard7.Ortho.'
#  'SurgicalWard7.Ortho.AcuteMedicalUnit.EAU'
#  'SurgicalWard7.Ortho.ClinicalDecisionUnit.PRUH'
#  'SurgicalWard7.Ortho.CoronaryCareUnit.PRUH.'
#  'SurgicalWard7.Ortho.FarnboroughWard'
#  'SurgicalWard7.Ortho.IntensiveCare.HighDepUnit.PRUH.'
#  'SurgicalWard7.Ortho.MedicalWard1' 'SurgicalWard7.Ortho.MedicalWard7'
#  'SurgicalWard7.Ortho.MedicalWard8' 'SurgicalWard7.Ortho.MedicalWard9'
#  'SurgicalWard7.Ortho.RecoveryWard1'
#  'SurgicalWard7.Ortho.SurgicalWard1.Darwin1.'
#  'SurgicalWard7.Ortho.SurgicalWard3.SAU.'
#  'SurgicalWard7.Ortho.SurgicalWard4' 'SurgicalWard7.Ortho.SurgicalWard5'
#  'SurgicalWard7.Ortho.SurgicalWard6']

# %%
#combining transfers that happen in both directions into only one direction
#this is then used for the non-directional network later on - ignore if directional graph is wanted

for index,row in PRUHData.iterrows():
    #if row['transfer'] in twoWayTransfers:
        #print(PRUHData.loc[index,'transfer_final'])
        if row.Source < row.Target:
            PRUHData.loc[index,'transfer_final'] = row.Source + row.Target
            PRUHData.loc[index,'source_final'] = row.Source
            PRUHData.loc[index,'target_final'] = row.Target
            #print(PRUHData.loc[index,'transfer_final'])
        elif row.Source > row.Target:
            PRUHData.loc[index,'transfer_final'] = row.Target + row.Source
            PRUHData.loc[index,'source_final'] = row.Target
            PRUHData.loc[index,'target_final'] = row.Source
            
        else:
            print('error - source: ',row.Source,' target: ',row.Target)
        #print(PRUHData.loc[index,'transfer_final'])
PRUHData.head()
# Out:
#                  Source Site_source         Target Site_target  Transfers  \
# 4  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 5  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          1
# 6  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 7  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 8  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          3
#
#    Year  Week                           transfer  \
# 4  2015     1  AcuteMedicalUnit.EAUChartwellUnit
# 5  2015     2  AcuteMedicalUnit.EAUChartwellUnit
# 6  2015     3  AcuteMedicalUnit.EAUChartwellUnit
# 7  2015     5  AcuteMedicalUnit.EAUChartwellUnit
# 8  2015     6  AcuteMedicalUnit.EAUChartwellUnit
#
#                   transfer_backwards                     transfer_final  \
# 4  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 5  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 6  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 7  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 8  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
#
#     target_final          source_final
# 4  ChartwellUnit  AcuteMedicalUnit.EAU
# 5  ChartwellUnit  AcuteMedicalUnit.EAU
# 6  ChartwellUnit  AcuteMedicalUnit.EAU
# 7  ChartwellUnit  AcuteMedicalUnit.EAU
# 8  ChartwellUnit  AcuteMedicalUnit.EAU

# %%
print(np.unique(PRUHData.transfer).shape)
print(np.unique(PRUHData.transfer_final).shape,np.unique(PRUHData.source_final).shape )
PRUHData.head()
# Out:
# (739,)
# (526,) (56,)
#                  Source Site_source         Target Site_target  Transfers  \
# 4  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 5  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          1
# 6  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 7  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 8  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          3
#
#    Year  Week                           transfer  \
# 4  2015     1  AcuteMedicalUnit.EAUChartwellUnit
# 5  2015     2  AcuteMedicalUnit.EAUChartwellUnit
# 6  2015     3  AcuteMedicalUnit.EAUChartwellUnit
# 7  2015     5  AcuteMedicalUnit.EAUChartwellUnit
# 8  2015     6  AcuteMedicalUnit.EAUChartwellUnit
#
#                   transfer_backwards                     transfer_final  \
# 4  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 5  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 6  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 7  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
# 8  ChartwellUnitAcuteMedicalUnit.EAU  AcuteMedicalUnit.EAUChartwellUnit
#
#     target_final          source_final
# 4  ChartwellUnit  AcuteMedicalUnit.EAU
# 5  ChartwellUnit  AcuteMedicalUnit.EAU
# 6  ChartwellUnit  AcuteMedicalUnit.EAU
# 7  ChartwellUnit  AcuteMedicalUnit.EAU
# 8  ChartwellUnit  AcuteMedicalUnit.EAU

# %%
#group data into total transfer between two nodes (either way) for the whole year

groupedData = PRUHData.groupby(['transfer', 'Target', 'Source', 'transfer_backwards'] ).sum()
groupedData = groupedData[groupedData['Transfers']>10]
print(groupedData.shape, type(groupedData))


newGroup = 
groupedData.head()
# Out:
#   File "<ipython-input-12-dcbe304227a4>", line 8
#     newGroup =
#                ^
# SyntaxError: invalid syntax

# %%
groupedData = PRUHData.groupby('transfer_final' ).agg({
    'Transfers': 'sum',
    'source_final': 'first',
    'target_final': 'first'
})
groupedData = groupedData[groupedData['Transfers']>10]
print(groupedData.shape, type(groupedData))

total_transfers = groupedData.Transfers.sum()
groupedData['weight'] = groupedData.Transfers/total_transfers
print(groupedData.head(10))
groupedData.columns.values
groupedData.head(10)

# %%
edges = []
for link in np.unique(PRUHData.transfer):
    print(link)
    sumOfTransfers = PRUHData[PRUHData['transfer'] == link].Transfers.sum())

# %%
G = nx.Graph()
G.add_nodes_from(PRUHWards[0:2])
G.add_nodes_from(PRUHWards[1:3])
G.add_edge(PRUHWards[0], PRUHWards[1], weight = 0.1)
G.add_edge(PRUHWards[1], PRUHWards[2], weight = 10)
G.add_edge(PRUHWards[2], PRUHWards[3], weight = 1)

edges = G.edges()
#colors = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

nx.draw(G, with_labels=True, font_weight='bold', width = weights)
plt.show()

# %%
G = nx.petersen_graph()
plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
plt.show()

# %%
weights_array = np.array(groupedData['weight'].values.tolist())

groupedData['weight_range'] = np.where(weights_array < 0.1, 0.1, weights_array).tolist()
weights_array = np.array(groupedData['weight_range'].values.tolist())
groupedData['weight_range'] = np.where(weights_array > 10, 10, weights_array).tolist()

groupedData.shape

# %%
network = nx.Graph()
network.add_nodes_from(np.unique(groupedData.source_final))
network.add_nodes_from(np.unique(groupedData.target_final))
for index,row in groupedData.iterrows():
    network.add_edge(row.source_final, row.target_final, weight = row.weight_range)
    
print(nx.info(network))
#network_weights = [network[u][v]['weight'] for u,v in edges]

nx.draw(network, with_labels=True, font_weight='bold', font_size=12)
#plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
print(nx.info(network))

# %%
allData.head()
