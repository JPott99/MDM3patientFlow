# %%
import numpy as np 
import pandas as pd
import networkx as nx 
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
allData = pd.read_csv("journal.pone.0185912.s003.csv")
allData.head()
# Out:
#                  Source Site_source         Target Site_target  Transfers  \
# 0  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          1
# 1  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 2  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 3  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          3
# 4  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
#
#    Year  Week
# 0  2014    48
# 1  2014    49
# 2  2014    50
# 3  2014    51
# 4  2015     1

# %%
allData.head()
# Out:
#                  Source Site_source         Target Site_target  Transfers  \
# 0  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          1
# 1  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 2  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
# 3  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          3
# 4  AcuteMedicalUnit.EAU        PRUH  ChartwellUnit        PRUH          2
#
#    Year  Week
# 0  2014    48
# 1  2014    49
# 2  2014    50
# 3  2014    51
# 4  2015     1

# %%
print(np.unique(allData.Site_source.values, return_counts=True))
print(np.unique(allData.Site_target.values, return_counts=True))
#allData.Site_source.values.nunique
# Out:
# (array(['DH', 'Orpington', 'PRUH'], dtype=object), array([17675,   291, 13372]))
# (array(['DH', 'Orpington', 'PRUH'], dtype=object), array([18121,   480, 12737]))

# %%
allData['FullSourceName'] = allData.Source + allData.Site_source
allData['FullTargetName'] = allData.Target + allData.Site_target

#allTransfers = np.intersect1d(np.unique(allData.FullSourceName),np.unique(allData.FullTargetName))
print(np.unique(allData.FullSourceName.values).shape)

print(np.unique(allData.FullTargetName.values).shape)
allTransfers = [i for i in np.unique(allData.FullTargetName) if i not in np.unique(allData.FullSourceName)]
print(len(allTransfers), allTransfers)
allTransfers = np.unique(allData.FullSourceName).tolist() + allTransfers 
print(len(allTransfers))
#allData.head()
# Out:
# (77,)
# (80,)
# 3 ['ExitHospitalDH', 'ExitHospitalOrpington', 'ExitHospitalPRUH']
# 80

# %%
allData['Transfer'] = allData.FullSourceName +'='+ allData.FullTargetName

groupedByTransfer = allData.groupby('Transfer').sum()
print(groupedByTransfer.head())
listOfEdges = []
j=0
for i in np.unique(allData.Transfer.values):
    a,b = i.split('=')
    listOfEdges.append([a,b])#,groupedByTransfer.Transfers.values[j]
    j += 1
len(listOfEdges)
#listOfEdges
# Out:
#                                                     Transfers    Year  Week
# Transfer
# AcuteMedicalUnit.EAUPRUH=ChartwellUnitPRUH                194  143084  1689
# AcuteMedicalUnit.EAUPRUH=CheereDH                           3    4029    98
# AcuteMedicalUnit.EAUPRUH=ChristineBrownCritical...          3    6044    78
# AcuteMedicalUnit.EAUPRUH=ClinicalDecisionUnit.P...         17   28213   421
# AcuteMedicalUnit.EAUPRUH=CoronaryCareUnit.PRUH....        413  169281  1979
# [['AcuteMedicalUnit.EAUPRUH', 'ChartwellUnitPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'CheereDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'ChristineBrownCriticalCareDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'CoronaryCareUnit.SamOram.DH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'CottonDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'DavidMarsdenDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'DischargeLoungePRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'DonneDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'ExitHospitalPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'FarnboroughDayWardPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'FarnboroughWardPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'Fisk.CheereHDUDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'FiskDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'GuthrieDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'KCH.EmergencyDeptDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'KatherineMonkDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'KinnierWilsonDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'KinnierWilsonHDUDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'LiverICUDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MaryRayDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard1PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard2PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard3PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard4PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard6PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard7PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard8PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'MedicalWard9PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'Ontario.ORP.Orpington'],
#  ['AcuteMedicalUnit.EAUPRUH', 'PlannedInvestigationUnitPRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'RDLawrenceDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'RecoveryWard1PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SamOramDH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard4PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard5PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard6PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['AcuteMedicalUnit.EAUPRUH', 'TheFriendsStrokeUnitDH'],
#  ['AcuteSurgicalUnitDH', 'ExitHospitalDH'],
#  ['AdultCysticFibrosisUnitDH', 'ExitHospitalDH'],
#  ['AdultCysticFibrosisUnitDH', 'LonsdaleDH'],
#  ['AdultCysticFibrosisUnitDH', 'MatthewWhitingDH'],
#  ['AdultCysticFibrosisUnitDH', 'OliverDH'],
#  ['AdultCysticFibrosisUnitDH', 'RDLawrenceDH'],
#  ['AdultCysticFibrosisUnitDH', 'TwiningDH'],
#  ['AnnieZunzDH', 'ByronDH'],
#  ['AnnieZunzDH', 'CheereDH'],
#  ['AnnieZunzDH', 'ChristineBrownCriticalCareDH'],
#  ['AnnieZunzDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['AnnieZunzDH', 'CoptcoatDH'],
#  ['AnnieZunzDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['AnnieZunzDH', 'CottonDH'],
#  ['AnnieZunzDH', 'DavidMarsdenDH'],
#  ['AnnieZunzDH', 'DavidsonDH'],
#  ['AnnieZunzDH', 'DawsonDH'],
#  ['AnnieZunzDH', 'DerekMitchellUnitDH'],
#  ['AnnieZunzDH', 'DonneDH'],
#  ['AnnieZunzDH', 'ElfandLibraDH'],
#  ['AnnieZunzDH', 'ExitHospitalDH'],
#  ['AnnieZunzDH', 'FarnboroughWardPRUH'],
#  ['AnnieZunzDH', 'FiskDH'],
#  ['AnnieZunzDH', 'FrankCookseyOrpington'],
#  ['AnnieZunzDH', 'GuthrieDH'],
#  ['AnnieZunzDH', 'HowardDH'],
#  ['AnnieZunzDH', 'KatherineMonkDH'],
#  ['AnnieZunzDH', 'ListerDH'],
#  ['AnnieZunzDH', 'LiverICUDH'],
#  ['AnnieZunzDH', 'LonsdaleDH'],
#  ['AnnieZunzDH', 'MarjorieWarrenDH'],
#  ['AnnieZunzDH', 'MaryRayDH'],
#  ['AnnieZunzDH', 'MatthewWhitingDH'],
#  ['AnnieZunzDH', 'MedicalCriticalCareUnitDH'],
#  ['AnnieZunzDH', 'MedihomeDH'],
#  ['AnnieZunzDH', 'MurrayFalconerDH'],
#  ['AnnieZunzDH', 'OliverDH'],
#  ['AnnieZunzDH', 'Ontario.ORP.Orpington'],
#  ['AnnieZunzDH', 'RDLawrenceDH'],
#  ['AnnieZunzDH', 'SamOramDH'],
#  ['AnnieZunzDH', 'SurgicalCriticalCareUnitDH'],
#  ['AnnieZunzDH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['AnnieZunzDH', 'TheFriendsStrokeUnitDH'],
#  ['AnnieZunzDH', 'ToddDH'],
#  ['AnnieZunzDH', 'TrundleDH'],
#  ['AnnieZunzDH', 'TwiningDH'],
#  ['AnnieZunzDH', 'Victoria.AlbertDH'],
#  ['AnnieZunzDH', 'Victoria.AlbertHDUDH'],
#  ['AnnieZunzDH', 'WaddingtonDH'],
#  ['Boddington.ORP.Orpington', 'AcuteMedicalUnit.EAUPRUH'],
#  ['Boddington.ORP.Orpington', 'CoptcoatDH'],
#  ['Boddington.ORP.Orpington', 'ExitHospitalOrpington'],
#  ['Boddington.ORP.Orpington', 'KCH.EmergencyDeptDH'],
#  ['Boddington.ORP.Orpington', 'MedicalWard9PRUH'],
#  ['Boddington.ORP.Orpington', 'PlannedInvestigationUnitPRUH'],
#  ['Boddington.ORP.Orpington', 'Quebec.ORP.Orpington'],
#  ['Boddington.ORP.Orpington', 'SurgicalWard3.SAU.PRUH'],
#  ['Boddington.ORP.Orpington', 'SurgicalWard5PRUH'],
#  ['Boddington.ORP.Orpington', 'SurgicalWard6PRUH'],
#  ['Boddington.ORP.Orpington', 'SurgicalWard7.Ortho.PRUH'],
#  ['Boddington.ORP.Orpington', 'TrundleDH'],
#  ['Boddington.ORP.Orpington', 'TwiningDH'],
#  ['BrunelAdmissionsLoungeDH', 'DawsonDH'],
#  ['BrunelAdmissionsLoungeDH', 'ExitHospitalDH'],
#  ['ByronDH', 'AnnieZunzDH'],
#  ['ByronDH', 'CheereDH'],
#  ['ByronDH', 'ChristineBrownCriticalCareDH'],
#  ['ByronDH', 'CottonDH'],
#  ['ByronDH', 'DavidMarsdenDH'],
#  ['ByronDH', 'DawsonDH'],
#  ['ByronDH', 'DonneDH'],
#  ['ByronDH', 'ElfandLibraDH'],
#  ['ByronDH', 'ExitHospitalDH'],
#  ['ByronDH', 'FiskDH'],
#  ['ByronDH', 'GuthrieDH'],
#  ['ByronDH', 'KatherineMonkDH'],
#  ['ByronDH', 'KinnierWilsonHDUDH'],
#  ['ByronDH', 'ListerDH'],
#  ['ByronDH', 'LiverICUDH'],
#  ['ByronDH', 'MarjorieWarrenDH'],
#  ['ByronDH', 'MaryRayDH'],
#  ['ByronDH', 'MedicalCriticalCareUnitDH'],
#  ['ByronDH', 'MedihomeDH'],
#  ['ByronDH', 'OliverDH'],
#  ['ByronDH', 'RDLawrenceDH'],
#  ['ByronDH', 'SamOramDH'],
#  ['ByronDH', 'SurgicalCriticalCareUnitDH'],
#  ['ByronDH', 'TheFriendsStrokeUnitDH'],
#  ['ByronDH', 'TrundleDH'],
#  ['ByronDH', 'TwiningDH'],
#  ['ByronDH', 'Victoria.AlbertDH'],
#  ['ByronDH', 'Victoria.AlbertHDUDH'],
#  ['ChartwellUnitPRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['ChartwellUnitPRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['ChartwellUnitPRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['ChartwellUnitPRUH', 'DavidsonDH'],
#  ['ChartwellUnitPRUH', 'DischargeLoungePRUH'],
#  ['ChartwellUnitPRUH', 'ElfandLibraDH'],
#  ['ChartwellUnitPRUH', 'ExitHospitalPRUH'],
#  ['ChartwellUnitPRUH', 'FarnboroughWardPRUH'],
#  ['ChartwellUnitPRUH', 'FiskDH'],
#  ['ChartwellUnitPRUH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['ChartwellUnitPRUH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['ChartwellUnitPRUH', 'KCH.EmergencyDeptDH'],
#  ['ChartwellUnitPRUH', 'LiverICUDH'],
#  ['ChartwellUnitPRUH', 'MedicalWard1PRUH'],
#  ['ChartwellUnitPRUH', 'MedicalWard3PRUH'],
#  ['ChartwellUnitPRUH', 'MedicalWard4PRUH'],
#  ['ChartwellUnitPRUH', 'MedicalWard6PRUH'],
#  ['ChartwellUnitPRUH', 'MedicalWard8PRUH'],
#  ['ChartwellUnitPRUH', 'MedicalWard9PRUH'],
#  ['ChartwellUnitPRUH', 'Ontario.ORP.Orpington'],
#  ['ChartwellUnitPRUH', 'PlannedInvestigationUnitPRUH'],
#  ['ChartwellUnitPRUH', 'RecoveryWard1PRUH'],
#  ['ChartwellUnitPRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['ChartwellUnitPRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['ChartwellUnitPRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['ChartwellUnitPRUH', 'SurgicalWard5PRUH'],
#  ['CheereDH', 'AnnieZunzDH'],
#  ['CheereDH', 'ByronDH'],
#  ['CheereDH', 'ChristineBrownCriticalCareDH'],
#  ['CheereDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['CheereDH', 'CoptcoatDH'],
#  ['CheereDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['CheereDH', 'CottonDH'],
#  ['CheereDH', 'DavidMarsdenDH'],
#  ['CheereDH', 'DavidsonDH'],
#  ['CheereDH', 'DawsonDH'],
#  ['CheereDH', 'DonneDH'],
#  ['CheereDH', 'ElfandLibraDH'],
#  ['CheereDH', 'ExitHospitalDH'],
#  ['CheereDH', 'Fisk.CheereHDUDH'],
#  ['CheereDH', 'FiskDH'],
#  ['CheereDH', 'GuthrieDH'],
#  ['CheereDH', 'HowardDH'],
#  ['CheereDH', 'KatherineMonkDH'],
#  ['CheereDH', 'KinnierWilsonDH'],
#  ['CheereDH', 'ListerDH'],
#  ['CheereDH', 'LiverICUDH'],
#  ['CheereDH', 'LonsdaleDH'],
#  ['CheereDH', 'MarjorieWarrenDH'],
#  ['CheereDH', 'MaryRayDH'],
#  ['CheereDH', 'MatthewWhitingDH'],
#  ['CheereDH', 'MedicalCriticalCareUnitDH'],
#  ['CheereDH', 'MedicalWard1PRUH'],
#  ['CheereDH', 'MedihomeDH'],
#  ['CheereDH', 'OliverDH'],
#  ['CheereDH', 'RDLawrenceDH'],
#  ['CheereDH', 'SamOramDH'],
#  ['CheereDH', 'SurgicalCriticalCareUnitDH'],
#  ['CheereDH', 'SurgicalWard6PRUH'],
#  ['CheereDH', 'TheFriendsStrokeUnitDH'],
#  ['CheereDH', 'ToddDH'],
#  ['CheereDH', 'TwiningDH'],
#  ['CheereDH', 'WaddingtonDH'],
#  ['ChristineBrownCriticalCareDH', 'AnnieZunzDH'],
#  ['ChristineBrownCriticalCareDH', 'ByronDH'],
#  ['ChristineBrownCriticalCareDH', 'CheereDH'],
#  ['ChristineBrownCriticalCareDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['ChristineBrownCriticalCareDH', 'CoptcoatDH'],
#  ['ChristineBrownCriticalCareDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['ChristineBrownCriticalCareDH', 'CottonDH'],
#  ['ChristineBrownCriticalCareDH', 'DavidMarsdenDH'],
#  ['ChristineBrownCriticalCareDH', 'DavidsonDH'],
#  ['ChristineBrownCriticalCareDH', 'DawsonDH'],
#  ['ChristineBrownCriticalCareDH', 'DerekMitchellUnitDH'],
#  ['ChristineBrownCriticalCareDH', 'DonneDH'],
#  ['ChristineBrownCriticalCareDH', 'ElfandLibraDH'],
#  ['ChristineBrownCriticalCareDH', 'ExitHospitalDH'],
#  ['ChristineBrownCriticalCareDH', 'Fisk.CheereHDUDH'],
#  ['ChristineBrownCriticalCareDH', 'FiskDH'],
#  ['ChristineBrownCriticalCareDH', 'GuthrieDH'],
#  ['ChristineBrownCriticalCareDH', 'HowardDH'],
#  ['ChristineBrownCriticalCareDH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['ChristineBrownCriticalCareDH', 'KCH.EmergencyDeptDH'],
#  ['ChristineBrownCriticalCareDH', 'KatherineMonkDH'],
#  ['ChristineBrownCriticalCareDH', 'KinnierWilsonDH'],
#  ['ChristineBrownCriticalCareDH', 'KinnierWilsonHDUDH'],
#  ['ChristineBrownCriticalCareDH', 'ListerDH'],
#  ['ChristineBrownCriticalCareDH', 'LiverICUDH'],
#  ['ChristineBrownCriticalCareDH', 'LonsdaleDH'],
#  ['ChristineBrownCriticalCareDH', 'MarjorieWarrenDH'],
#  ['ChristineBrownCriticalCareDH', 'MaryRayDH'],
#  ['ChristineBrownCriticalCareDH', 'MatthewWhitingDH'],
#  ['ChristineBrownCriticalCareDH', 'MedicalCriticalCareUnitDH'],
#  ['ChristineBrownCriticalCareDH', 'MedicalWard8PRUH'],
#  ['ChristineBrownCriticalCareDH', 'MurrayFalconerDH'],
#  ['ChristineBrownCriticalCareDH', 'OliverDH'],
#  ['ChristineBrownCriticalCareDH', 'RDLawrenceDH'],
#  ['ChristineBrownCriticalCareDH', 'SamOramDH'],
#  ['ChristineBrownCriticalCareDH', 'SurgicalCriticalCareUnitDH'],
#  ['ChristineBrownCriticalCareDH', 'TheFriendsStrokeUnitDH'],
#  ['ChristineBrownCriticalCareDH', 'ToddDH'],
#  ['ChristineBrownCriticalCareDH', 'TrundleDH'],
#  ['ChristineBrownCriticalCareDH', 'TwiningDH'],
#  ['ChristineBrownCriticalCareDH', 'Victoria.AlbertDH'],
#  ['ChristineBrownCriticalCareDH', 'Victoria.AlbertHDUDH'],
#  ['ChristineBrownCriticalCareDH', 'WaddingtonDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'AnnieZunzDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ByronDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'CheereDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ChristineBrownCriticalCareDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'CoptcoatDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'CottonDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'DavidMarsdenDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'DavidsonDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'DawsonDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'DerekMitchellUnitDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'DonneDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ElfandLibraDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ExitHospitalDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'Fisk.CheereHDUDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'FiskDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'GuthrieDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'HowardDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'KCH.EmergencyDeptDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'KatherineMonkDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'KinnierWilsonDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'KinnierWilsonHDUDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ListerDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'LiverICUDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'LonsdaleDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MarjorieWarrenDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MaryRayDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MatthewWhitingDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MedicalCriticalCareUnitDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MedicalWard9PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MedihomeDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'MurrayFalconerDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'OliverDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'RDLawrenceDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SamOramDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SurgicalCriticalCareUnitDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SurgicalWard3.SAU.PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SurgicalWard5PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'SurgicalWard6PRUH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'TheFriendsStrokeUnitDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'ToddDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'TrundleDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'TwiningDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'Victoria.AlbertDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'Victoria.AlbertHDUDH'],
#  ['ClinicalDecisionUnit.A.E..DHDH', 'WaddingtonDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'Boddington.ORP.Orpington'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'ChartwellUnitPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'ChristineBrownCriticalCareDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'CoronaryCareUnit.SamOram.DH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'DavidMarsdenDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'DischargeLoungePRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'ExitHospitalPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'FarnboroughWardPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'KCH.EmergencyDeptDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'KatherineMonkDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'KinnierWilsonDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'ListerDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MatthewWhitingDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard1PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard2PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard3PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard4PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard6PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard7PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard8PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'MedicalWard9PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'Ontario.ORP.Orpington'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'PRUH.EmergencyDeptPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'PlannedInvestigationUnitPRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'RecoveryWard1PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SamOramDH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard4PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard5PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard6PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['ClinicalDecisionUnit.PRUHPRUH', 'TheFriendsStrokeUnitDH'],
#  ['CoptcoatDH', 'CheereDH'],
#  ['CoptcoatDH', 'ChristineBrownCriticalCareDH'],
#  ['CoptcoatDH', 'CottonDH'],
#  ['CoptcoatDH', 'DawsonDH'],
#  ['CoptcoatDH', 'DonneDH'],
#  ['CoptcoatDH', 'ElfandLibraDH'],
#  ['CoptcoatDH', 'ExitHospitalDH'],
#  ['CoptcoatDH', 'FiskDH'],
#  ['CoptcoatDH', 'GuthrieDH'],
#  ['CoptcoatDH', 'HowardDH'],
#  ['CoptcoatDH', 'KatherineMonkDH'],
#  ['CoptcoatDH', 'ListerDH'],
#  ['CoptcoatDH', 'LiverICUDH'],
#  ['CoptcoatDH', 'MatthewWhitingDH'],
#  ['CoptcoatDH', 'MedicalCriticalCareUnitDH'],
#  ['CoptcoatDH', 'OliverDH'],
#  ['CoptcoatDH', 'SurgicalCriticalCareUnitDH'],
#  ['CoptcoatDH', 'SurgicalWard6PRUH'],
#  ['CoptcoatDH', 'ToddDH'],
#  ['CoptcoatDH', 'TrundleDH'],
#  ['CoptcoatDH', 'TwiningDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'Boddington.ORP.Orpington'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'ChartwellUnitPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'ChristineBrownCriticalCareDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'CoronaryCareUnit.SamOram.DH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'CottonDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'DischargeLoungePRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'DonneDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'ExitHospitalPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'FarnboroughWardPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'FiskDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'GuthrieDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'KCH.EmergencyDeptDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard1PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard2PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard3PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard4PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard6PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard7PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard8PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'MedicalWard9PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'PlannedInvestigationUnitPRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SamOramDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalCriticalCareUnitDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard4PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard5PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard6PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'Victoria.AlbertDH'],
#  ['CoronaryCareUnit.PRUH.PRUH', 'Victoria.AlbertHDUDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'ByronDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'ChristineBrownCriticalCareDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['CoronaryCareUnit.SamOram.DH', 'CottonDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'DischargeLoungePRUH'],
#  ['CoronaryCareUnit.SamOram.DH', 'ElfandLibraDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'ExitHospitalDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'LiverICUDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'LonsdaleDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'MedicalCriticalCareUnitDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'MedicalWard8PRUH'],
#  ['CoronaryCareUnit.SamOram.DH', 'OliverDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'SamOramDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'SurgicalCriticalCareUnitDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'TwiningDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'Victoria.AlbertDH'],
#  ['CoronaryCareUnit.SamOram.DH', 'Victoria.AlbertHDUDH'],
#  ['CottonDH', 'AnnieZunzDH'],
#  ['CottonDH', 'ByronDH'],
#  ['CottonDH', 'CheereDH'],
#  ['CottonDH', 'ChristineBrownCriticalCareDH'],
#  ['CottonDH', 'CoptcoatDH'],
#  ['CottonDH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['CottonDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['CottonDH', 'DavidsonDH'],
#  ['CottonDH', 'DawsonDH'],
#  ['CottonDH', 'DerekMitchellUnitDH'],
#  ['CottonDH', 'DonneDH'],
#  ['CottonDH', 'ElfandLibraDH'],
#  ['CottonDH', 'ExitHospitalDH'],
#  ['CottonDH', 'FiskDH'],
#  ['CottonDH', 'GuthrieDH'],
#  ['CottonDH', 'HowardDH'],
#  ['CottonDH', 'KatherineMonkDH'],
#  ['CottonDH', 'ListerDH'],
#  ['CottonDH', 'LiverICUDH'],
#  ['CottonDH', 'LonsdaleDH'],
#  ['CottonDH', 'MarjorieWarrenDH'],
#  ['CottonDH', 'MaryRayDH'],
#  ['CottonDH', 'MatthewWhitingDH'],
#  ['CottonDH', 'MedicalCriticalCareUnitDH'],
#  ['CottonDH', 'MedicalWard2PRUH'],
#  ['CottonDH', 'MedicalWard8PRUH'],
#  ['CottonDH', 'MedihomeDH'],
#  ['CottonDH', 'MurrayFalconerDH'],
#  ['CottonDH', 'OliverDH'],
#  ['CottonDH', 'RDLawrenceDH'],
#  ['CottonDH', 'SamOramDH'],
#  ['CottonDH', 'SurgicalCriticalCareUnitDH'],
#  ['CottonDH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['CottonDH', 'TheFriendsStrokeUnitDH'],
#  ['CottonDH', 'ToddDH'],
#  ['CottonDH', 'TrundleDH'],
#  ['CottonDH', 'TwiningDH'],
#  ['CottonDH', 'Victoria.AlbertDH'],
#  ['CottonDH', 'Victoria.AlbertHDUDH'],
#  ['CottonDH', 'WaddingtonDH'],
#  ['DavidMarsdenDH', 'AnnieZunzDH'],
#  ['DavidMarsdenDH', 'ByronDH'],
#  ['DavidMarsdenDH', 'ChristineBrownCriticalCareDH'],
#  ['DavidMarsdenDH', 'CottonDH'],
#  ['DavidMarsdenDH', 'DavidsonDH'],
#  ['DavidMarsdenDH', 'DawsonDH'],
#  ['DavidMarsdenDH', 'DerekMitchellUnitDH'],
#  ['DavidMarsdenDH', 'DonneDH'],
#  ['DavidMarsdenDH', 'ExitHospitalDH'],
#  ['DavidMarsdenDH', 'FarnboroughWardPRUH'],
#  ['DavidMarsdenDH', 'FiskDH'],
#  ['DavidMarsdenDH', 'FrankCookseyOrpington'],
#  ['DavidMarsdenDH', 'GuthrieDH'],
#  ['DavidMarsdenDH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['DavidMarsdenDH', 'KCH.EmergencyDeptDH'],
#  ['DavidMarsdenDH', 'KatherineMonkDH'],
#  ['DavidMarsdenDH', 'KinnierWilsonDH'],
#  ['DavidMarsdenDH', 'KinnierWilsonHDUDH'],
#  ['DavidMarsdenDH', 'ListerDH'],
#  ['DavidMarsdenDH', 'LiverICUDH'],
#  ['DavidMarsdenDH', 'LonsdaleDH'],
#  ['DavidMarsdenDH', 'MarjorieWarrenDH'],
#  ['DavidMarsdenDH', 'MaryRayDH'],
#  ['DavidMarsdenDH', 'MatthewWhitingDH'],
#  ['DavidMarsdenDH', 'MedicalCriticalCareUnitDH'],
#  ['DavidMarsdenDH', 'MedicalWard1PRUH'],
#  ['DavidMarsdenDH', 'MedicalWard3PRUH'],
#  ['DavidMarsdenDH', 'MedicalWard4PRUH'],
#  ['DavidMarsdenDH', 'MedicalWard6PRUH'],
#  ['DavidMarsdenDH', 'MedicalWard9PRUH'],
#  ['DavidMarsdenDH', 'MedihomeDH'],
#  ['DavidMarsdenDH', 'MurrayFalconerDH'],
#  ['DavidMarsdenDH', 'OliverDH'],
#  ['DavidMarsdenDH', 'Ontario.ORP.Orpington'],
#  ['DavidMarsdenDH', 'StrokeUnit.PRUH.PRUH'],
#  ['DavidMarsdenDH', 'SurgicalCriticalCareUnitDH'],
#  ['DavidMarsdenDH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['DavidMarsdenDH', 'TheFriendsStrokeUnitDH'],
#  ['DavidMarsdenDH', 'TrundleDH'],
#  ['DavidMarsdenDH', 'TwiningDH'],
#  ['DavidMarsdenDH', 'Victoria.AlbertDH'],
#  ['DavidsonDH', 'AnnieZunzDH'],
#  ['DavidsonDH', 'ByronDH'],
#  ['DavidsonDH', 'ChartwellUnitPRUH'],
#  ['DavidsonDH', 'ChristineBrownCriticalCareDH'],
#  ['DavidsonDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['DavidsonDH', 'CoptcoatDH'],
#  ['DavidsonDH', 'CottonDH'],
#  ['DavidsonDH', 'DavidMarsdenDH'],
#  ['DavidsonDH', 'DawsonDH'],
#  ['DavidsonDH', 'DerekMitchellUnitDH'],
#  ['DavidsonDH', 'DonneDH'],
#  ['DavidsonDH', 'ElfandLibraDH'],
#  ['DavidsonDH', 'ExitHospitalDH'],
#  ['DavidsonDH', 'FiskDH'],
#  ['DavidsonDH', 'GuthrieDH'],
#  ['DavidsonDH', 'HowardDH'],
#  ['DavidsonDH', 'KatherineMonkDH'],
#  ['DavidsonDH', 'ListerDH'],
#  ['DavidsonDH', 'LiverICUDH'],
#  ['DavidsonDH', 'LonsdaleDH'],
#  ['DavidsonDH', 'MarjorieWarrenDH'],
#  ['DavidsonDH', 'MaryRayDH'],
#  ['DavidsonDH', 'MatthewWhitingDH'],
#  ['DavidsonDH', 'MedicalCriticalCareUnitDH'],
#  ['DavidsonDH', 'OliverDH'],
#  ['DavidsonDH', 'RDLawrenceDH'],
#  ['DavidsonDH', 'SamOramDH'],
#  ['DavidsonDH', 'SurgicalCriticalCareUnitDH'],
#  ['DavidsonDH', 'TheFriendsStrokeUnitDH'],
#  ['DavidsonDH', 'TwiningDH'],
#  ['DavidsonDH', 'Victoria.AlbertDH'],
#  ['DavidsonDH', 'Victoria.AlbertHDUDH'],
#  ['DavidsonDH', 'WaddingtonDH'],
#  ['DawsonDH', 'AnnieZunzDH'],
#  ['DawsonDH', 'ByronDH'],
#  ['DawsonDH', 'CheereDH'],
#  ['DawsonDH', 'ChristineBrownCriticalCareDH'],
#  ['DawsonDH', 'CoptcoatDH'],
#  ['DawsonDH', 'CottonDH'],
#  ['DawsonDH', 'DavidMarsdenDH'],
#  ['DawsonDH', 'DavidsonDH'],
#  ['DawsonDH', 'DonneDH'],
#  ['DawsonDH', 'ElfandLibraDH'],
#  ['DawsonDH', 'ExitHospitalDH'],
#  ['DawsonDH', 'FiskDH'],
#  ['DawsonDH', 'GuthrieDH'],
#  ['DawsonDH', 'HowardDH'],
#  ['DawsonDH', 'KatherineMonkDH'],
#  ['DawsonDH', 'KinnierWilsonDH'],
#  ['DawsonDH', 'ListerDH'],
#  ['DawsonDH', 'LiverICUDH'],
#  ['DawsonDH', 'MarjorieWarrenDH'],
#  ['DawsonDH', 'MaryRayDH'],
#  ['DawsonDH', 'MatthewWhitingDH'],
#  ['DawsonDH', 'MedicalCriticalCareUnitDH'],
#  ['DawsonDH', 'MedihomeDH'],
#  ['DawsonDH', 'OliverDH'],
#  ['DawsonDH', 'RDLawrenceDH'],
#  ['DawsonDH', 'SurgicalCriticalCareUnitDH'],
#  ['DawsonDH', 'ToddDH'],
#  ['DawsonDH', 'TwiningDH'],
#  ['DerekMitchellUnitDH', 'AnnieZunzDH'],
#  ['DerekMitchellUnitDH', 'ChristineBrownCriticalCareDH'],
#  ['DerekMitchellUnitDH', 'CottonDH'],
#  ['DerekMitchellUnitDH', 'DavidMarsdenDH'],
#  ['DerekMitchellUnitDH', 'DavidsonDH'],
#  ['DerekMitchellUnitDH', 'DawsonDH'],
#  ['DerekMitchellUnitDH', 'ElfandLibraDH'],
#  ['DerekMitchellUnitDH', 'ExitHospitalDH'],
#  ['DerekMitchellUnitDH', 'GuthrieDH'],
#  ['DerekMitchellUnitDH', 'LiverICUDH'],
#  ['DerekMitchellUnitDH', 'MarjorieWarrenDH'],
#  ['DerekMitchellUnitDH', 'MedicalCriticalCareUnitDH'],
#  ['DerekMitchellUnitDH', 'MurrayFalconerDH'],
#  ['DerekMitchellUnitDH', 'SurgicalCriticalCareUnitDH'],
#  ['DerekMitchellUnitDH', 'TheFriendsStrokeUnitDH'],
#  ['DerekMitchellUnitDH', 'TwiningDH'],
#  ['DerekMitchellUnitDH', 'Victoria.AlbertDH'],
#  ['DerekMitchellUnitDH', 'Victoria.AlbertHDUDH'],
#  ['DerekMitchellUnitDH', 'WaddingtonDH'],
#  ['DischargeLoungePRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['DischargeLoungePRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['DischargeLoungePRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['DischargeLoungePRUH', 'ExitHospitalPRUH'],
#  ['DischargeLoungePRUH', 'FarnboroughWardPRUH'],
#  ['DischargeLoungePRUH', 'KCH.EmergencyDeptDH'],
#  ['DischargeLoungePRUH', 'MedicalWard2PRUH'],
#  ['DischargeLoungePRUH', 'MedicalWard4PRUH'],
#  ['DischargeLoungePRUH', 'MedicalWard7PRUH'],
#  ['DischargeLoungePRUH', 'MedicalWard9PRUH'],
#  ['DischargeLoungePRUH', 'MedihomeDH'],
#  ['DischargeLoungePRUH', 'Ontario.ORP.Orpington'],
#  ['DischargeLoungePRUH', 'PlannedInvestigationUnitPRUH'],
#  ['DischargeLoungePRUH', 'RecoveryWard1PRUH'],
#  ['DonneDH', 'AnnieZunzDH'],
#  ['DonneDH', 'ByronDH'],
#  ['DonneDH', 'ChristineBrownCriticalCareDH'],
#  ['DonneDH', 'DawsonDH'],
#  ['DonneDH', 'ExitHospitalDH'],
#  ['DonneDH', 'FiskDH'],
#  ['DonneDH', 'FrankCookseyOrpington'],
#  ['DonneDH', 'KatherineMonkDH'],
#  ['DonneDH', 'MarjorieWarrenDH'],
#  ['DonneDH', 'MaryRayDH'],
#  ['DonneDH', 'MatthewWhitingDH'],
#  ['DonneDH', 'MedicalCriticalCareUnitDH'],
#  ['DonneDH', 'MedihomeDH'],
#  ['DonneDH', 'MurrayFalconerDH'],
#  ['DonneDH', 'OliverDH'],
#  ['DonneDH', 'SurgicalCriticalCareUnitDH'],
#  ['DonneDH', 'TheFriendsStrokeUnitDH'],
#  ['DonneDH', 'WaddingtonDH'],
#  ['ElfandLibraDH', 'AnnieZunzDH'],
#  ['ElfandLibraDH', 'ByronDH'],
#  ['ElfandLibraDH', 'CheereDH'],
#  ['ElfandLibraDH', 'ChristineBrownCriticalCareDH'],
#  ['ElfandLibraDH', 'CoptcoatDH'],
#  ['ElfandLibraDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['ElfandLibraDH', 'CottonDH'],
#  ['ElfandLibraDH', 'DavidMarsdenDH'],
#  ['ElfandLibraDH', 'DavidsonDH'],
#  ['ElfandLibraDH', 'DerekMitchellUnitDH'],
#  ['ElfandLibraDH', 'DonneDH'],
#  ['ElfandLibraDH', 'ExitHospitalDH'],
#  ['ElfandLibraDH', 'FiskDH'],
#  ['ElfandLibraDH', 'GuthrieDH'],
#  ['ElfandLibraDH', 'HowardDH'],
#  ['ElfandLibraDH', 'KatherineMonkDH'],
#  ['ElfandLibraDH', 'ListerDH'],
#  ['ElfandLibraDH', 'LiverICUDH'],
#  ['ElfandLibraDH', 'MarjorieWarrenDH'],
#  ['ElfandLibraDH', 'MaryRayDH'],
#  ['ElfandLibraDH', 'MatthewWhitingDH'],
#  ['ElfandLibraDH', 'MedicalCriticalCareUnitDH'],
#  ['ElfandLibraDH', 'MedihomeDH'],
#  ['ElfandLibraDH', 'MurrayFalconerDH'],
#  ['ElfandLibraDH', 'OliverDH'],
#  ['ElfandLibraDH', 'RDLawrenceDH'],
#  ['ElfandLibraDH', 'SamOramDH'],
#  ['ElfandLibraDH', 'SurgicalCriticalCareUnitDH'],
#  ['ElfandLibraDH', 'TwiningDH'],
#  ['ElfandLibraDH', 'Victoria.AlbertHDUDH'],
#  ['ElfandLibraDH', 'WaddingtonDH'],
#  ['FarnboroughDayWardPRUH', 'DavidMarsdenDH'],
#  ['FarnboroughDayWardPRUH', 'ExitHospitalPRUH'],
#  ['FarnboroughDayWardPRUH', 'FarnboroughWardPRUH'],
#  ['FarnboroughDayWardPRUH', 'FiskDH'],
#  ['FarnboroughDayWardPRUH', 'RecoveryWard1PRUH'],
#  ['FarnboroughWardPRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['FarnboroughWardPRUH', 'Boddington.ORP.Orpington'],
#  ['FarnboroughWardPRUH', 'ChartwellUnitPRUH'],
#  ['FarnboroughWardPRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['FarnboroughWardPRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['FarnboroughWardPRUH', 'CottonDH'],
#  ['FarnboroughWardPRUH', 'DavidMarsdenDH'],
#  ['FarnboroughWardPRUH', 'DischargeLoungePRUH'],
#  ['FarnboroughWardPRUH', 'ExitHospitalPRUH'],
#  ['FarnboroughWardPRUH', 'FiskDH'],
#  ['FarnboroughWardPRUH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['FarnboroughWardPRUH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['FarnboroughWardPRUH', 'KCH.EmergencyDeptDH'],
#  ['FarnboroughWardPRUH', 'LonsdaleDH'],
#  ['FarnboroughWardPRUH', 'MedicalWard1PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard2PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard3PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard4PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard6PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard7PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard8PRUH'],
#  ['FarnboroughWardPRUH', 'MedicalWard9PRUH'],
#  ['FarnboroughWardPRUH', 'Ontario.ORP.Orpington'],
#  ['FarnboroughWardPRUH', 'PlannedInvestigationUnitPRUH'],
#  ['FarnboroughWardPRUH', 'RecoveryWard1PRUH'],
#  ['FarnboroughWardPRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard4PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard5PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard6PRUH'],
#  ['FarnboroughWardPRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['FarnboroughWardPRUH', 'ToddDH'],
#  ['Fisk.CheereHDUDH', 'CheereDH'],
#  ['Fisk.CheereHDUDH', 'DawsonDH'],
#  ['Fisk.CheereHDUDH', 'ExitHospitalDH'],
#  ['Fisk.CheereHDUDH', 'FiskDH'],
#  ['Fisk.CheereHDUDH', 'KatherineMonkDH'],
#  ['Fisk.CheereHDUDH', 'MaryRayDH'],
#  ['Fisk.CheereHDUDH', 'MedicalCriticalCareUnitDH'],
#  ['FiskDH', 'AnnieZunzDH'],
#  ['FiskDH', 'ByronDH'],
#  ['FiskDH', 'CheereDH'],
#  ['FiskDH', 'ChristineBrownCriticalCareDH'],
#  ['FiskDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['FiskDH', 'CoptcoatDH'],
#  ['FiskDH', 'CottonDH'],
#  ['FiskDH', 'DavidMarsdenDH'],
#  ['FiskDH', 'DavidsonDH'],
#  ['FiskDH', 'DawsonDH'],
#  ['FiskDH', 'DerekMitchellUnitDH'],
#  ['FiskDH', 'DonneDH'],
#  ['FiskDH', 'ElfandLibraDH'],
#  ['FiskDH', 'ExitHospitalDH'],
#  ['FiskDH', 'Fisk.CheereHDUDH'],
#  ['FiskDH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['FiskDH', 'HowardDH'],
#  ['FiskDH', 'KCH.EmergencyDeptDH'],
#  ['FiskDH', 'KatherineMonkDH'],
#  ['FiskDH', 'ListerDH'],
#  ['FiskDH', 'LiverICUDH'],
#  ['FiskDH', 'LonsdaleDH'],
#  ['FiskDH', 'MarjorieWarrenDH'],
#  ['FiskDH', 'MaryRayDH'],
#  ['FiskDH', 'MatthewWhitingDH'],
#  ['FiskDH', 'MedicalCriticalCareUnitDH'],
#  ['FiskDH', 'MedicalWard3PRUH'],
#  ['FiskDH', 'MedihomeDH'],
#  ['FiskDH', 'OliverDH'],
#  ['FiskDH', 'RDLawrenceDH'],
#  ['FiskDH', 'StrokeUnit.PRUH.PRUH'],
#  ['FiskDH', 'SurgicalCriticalCareUnitDH'],
#  ['FiskDH', 'TheFriendsStrokeUnitDH'],
#  ['FiskDH', 'ToddDH'],
#  ['FiskDH', 'TrundleDH'],
#  ['FiskDH', 'TwiningDH'],
#  ['FiskDH', 'WaddingtonDH'],
#  ['FrankCookseyOrpington', 'ExitHospitalOrpington'],
#  ['FrankCookseyOrpington', 'FarnboroughWardPRUH'],
#  ['FrankCookseyOrpington', 'ListerDH'],
#  ['FrankCookseyOrpington', 'OliverDH'],
#  ['FrankCookseyOrpington', 'Ontario.ORP.Orpington'],
#  ['FrankCookseyOrpington', 'RDLawrenceDH'],
#  ['FrankCookseyOrpington', 'SurgicalWard5PRUH'],
#  ['FrankCookseyOrpington', 'TheFriendsStrokeUnitDH'],
#  ['GuthrieDH', 'ChristineBrownCriticalCareDH'],
#  ['GuthrieDH', 'CoptcoatDH'],
#  ['GuthrieDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['GuthrieDH', 'CottonDH'],
#  ['GuthrieDH', 'DavidMarsdenDH'],
#  ['GuthrieDH', 'DavidsonDH'],
#  ['GuthrieDH', 'DawsonDH'],
#  ['GuthrieDH', 'DerekMitchellUnitDH'],
#  ['GuthrieDH', 'ElfandLibraDH'],
#  ['GuthrieDH', 'ExitHospitalDH'],
#  ['GuthrieDH', 'HowardDH'],
#  ['GuthrieDH', 'KatherineMonkDH'],
#  ['GuthrieDH', 'KinnierWilsonDH'],
#  ['GuthrieDH', 'KinnierWilsonHDUDH'],
#  ['GuthrieDH', 'ListerDH'],
#  ['GuthrieDH', 'LiverICUDH'],
#  ['GuthrieDH', 'MatthewWhitingDH'],
#  ['GuthrieDH', 'MedicalCriticalCareUnitDH'],
#  ['GuthrieDH', 'MurrayFalconerDH'],
#  ['GuthrieDH', 'SamOramDH'],
#  ['GuthrieDH', 'SurgicalCriticalCareUnitDH'],
#  ['GuthrieDH', 'ToddDH'],
#  ['GuthrieDH', 'TrundleDH'],
#  ['GuthrieDH', 'TwiningDH'],
#  ['GuthrieDH', 'Victoria.AlbertDH'],
#  ['GuthrieDH', 'Victoria.AlbertHDUDH'],
#  ['GuthrieDH', 'WaddingtonDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'ChartwellUnitPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'CottonDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'DavidMarsdenDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'DischargeLoungePRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'ExitHospitalPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'FarnboroughWardPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'FiskDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH',
#   'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'KCH.EmergencyDeptDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'KinnierWilsonDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'KinnierWilsonHDUDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalCriticalCareUnitDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard1PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard2PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard3PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard4PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard6PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard7PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard8PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'MedicalWard9PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'PlannedInvestigationUnitPRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard4PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard5PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard6PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'TheFriendsStrokeUnitDH'],
#  ['HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 'Victoria.AlbertHDUDH'],
#  ['HowardDH', 'AnnieZunzDH'],
#  ['HowardDH', 'ByronDH'],
#  ['HowardDH', 'CheereDH'],
#  ['HowardDH', 'ChristineBrownCriticalCareDH'],
#  ['HowardDH', 'CoptcoatDH'],
#  ['HowardDH', 'DavidsonDH'],
#  ['HowardDH', 'DawsonDH'],
#  ['HowardDH', 'ElfandLibraDH'],
#  ['HowardDH', 'ExitHospitalDH'],
#  ['HowardDH', 'Fisk.CheereHDUDH'],
#  ['HowardDH', 'FiskDH'],
#  ['HowardDH', 'KatherineMonkDH'],
#  ['HowardDH', 'KinnierWilsonHDUDH'],
#  ['HowardDH', 'ListerDH'],
#  ['HowardDH', 'LiverICUDH'],
#  ['HowardDH', 'MaryRayDH'],
#  ['HowardDH', 'MatthewWhitingDH'],
#  ['HowardDH', 'MedicalCriticalCareUnitDH'],
#  ['HowardDH', 'MedicalWard6PRUH'],
#  ['HowardDH', 'MedihomeDH'],
#  ['HowardDH', 'OliverDH'],
#  ['HowardDH', 'RDLawrenceDH'],
#  ['HowardDH', 'SurgicalCriticalCareUnitDH'],
#  ['HowardDH', 'ToddDH'],
#  ['HowardDH', 'TwiningDH'],
#  ['HowardDH', 'WaddingtonDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'ChartwellUnitPRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'ChristineBrownCriticalCareDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'DischargeLoungePRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'ExitHospitalPRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'FarnboroughDayWardPRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'FarnboroughWardPRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'Fisk.CheereHDUDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'FiskDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH',
#   'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'KCH.EmergencyDeptDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'LiverICUDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalCriticalCareUnitDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard1PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard2PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard3PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard4PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard6PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard7PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'MedicalWard8PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'StrokeUnit.PRUH.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalCriticalCareUnitDH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard1.Darwin1.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard2.Darwin2.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard3.SAU.PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard4PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard5PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard6PRUH'],
#  ['IntensiveCare.HighDepUnit.PRUH.PRUH', 'SurgicalWard7.Ortho.PRUH'],
#  ['KCH.EmergencyDeptDH', 'AcuteMedicalUnit.EAUPRUH'],
#  ['KCH.EmergencyDeptDH', 'AcuteSurgicalUnitDH'],
#  ['KCH.EmergencyDeptDH', 'AdultCysticFibrosisUnitDH'],
#  ['KCH.EmergencyDeptDH', 'AnnieZunzDH'],
#  ['KCH.EmergencyDeptDH', 'ByronDH'],
#  ['KCH.EmergencyDeptDH', 'CheereDH'],
#  ['KCH.EmergencyDeptDH', 'ChristineBrownCriticalCareDH'],
#  ['KCH.EmergencyDeptDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['KCH.EmergencyDeptDH', 'ClinicalDecisionUnit.PRUHPRUH'],
#  ['KCH.EmergencyDeptDH', 'CoptcoatDH'],
#  ['KCH.EmergencyDeptDH', 'CoronaryCareUnit.PRUH.PRUH'],
#  ['KCH.EmergencyDeptDH', 'CoronaryCareUnit.SamOram.DH'],
#  ['KCH.EmergencyDeptDH', 'CottonDH'],
#  ['KCH.EmergencyDeptDH', 'DavidMarsdenDH'],
#  ['KCH.EmergencyDeptDH', 'DavidsonDH'],
#  ['KCH.EmergencyDeptDH', 'DawsonDH'],
#  ['KCH.EmergencyDeptDH', 'DerekMitchellUnitDH'],
#  ['KCH.EmergencyDeptDH', 'DonneDH'],
#  ['KCH.EmergencyDeptDH', 'ElfandLibraDH'],
#  ['KCH.EmergencyDeptDH', 'ExitHospitalDH'],
#  ['KCH.EmergencyDeptDH', 'FarnboroughWardPRUH'],
#  ['KCH.EmergencyDeptDH', 'Fisk.CheereHDUDH'],
#  ['KCH.EmergencyDeptDH', 'FiskDH'],
#  ['KCH.EmergencyDeptDH', 'FrankCookseyOrpington'],
#  ['KCH.EmergencyDeptDH', 'GuthrieDH'],
#  ['KCH.EmergencyDeptDH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['KCH.EmergencyDeptDH', 'HowardDH'],
#  ['KCH.EmergencyDeptDH', 'KatherineMonkDH'],
#  ['KCH.EmergencyDeptDH', 'KinnierWilsonDH'],
#  ['KCH.EmergencyDeptDH', 'KinnierWilsonHDUDH'],
#  ['KCH.EmergencyDeptDH', 'ListerDH'],
#  ['KCH.EmergencyDeptDH', 'LiverICUDH'],
#  ['KCH.EmergencyDeptDH', 'LonsdaleDH'],
#  ['KCH.EmergencyDeptDH', 'MarjorieWarrenDH'],
#  ['KCH.EmergencyDeptDH', 'MaryRayDH'],
#  ['KCH.EmergencyDeptDH', 'MatthewWhitingDH'],
#  ['KCH.EmergencyDeptDH', 'MedicalCriticalCareUnitDH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard1PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard3PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard6PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard7PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard8PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedicalWard9PRUH'],
#  ['KCH.EmergencyDeptDH', 'MedihomeDH'],
#  ['KCH.EmergencyDeptDH', 'MurrayFalconerDH'],
#  ['KCH.EmergencyDeptDH', 'OliverDH'],
#  ['KCH.EmergencyDeptDH', 'Ontario.ORP.Orpington'],
#  ['KCH.EmergencyDeptDH', 'RDLawrenceDH'],
#  ['KCH.EmergencyDeptDH', 'RecoveryWard1PRUH'],
#  ['KCH.EmergencyDeptDH', 'SamOramDH'],
#  ['KCH.EmergencyDeptDH', 'SurgicalCriticalCareUnitDH'],
#  ['KCH.EmergencyDeptDH', 'SurgicalWard3.SAU.PRUH'],
#  ['KCH.EmergencyDeptDH', 'SurgicalWard4PRUH'],
#  ['KCH.EmergencyDeptDH', 'SurgicalWard5PRUH'],
#  ['KCH.EmergencyDeptDH', 'SurgicalWard6PRUH'],
#  ['KCH.EmergencyDeptDH', 'TheFriendsStrokeUnitDH'],
#  ['KCH.EmergencyDeptDH', 'ToddDH'],
#  ['KCH.EmergencyDeptDH', 'TrundleDH'],
#  ['KCH.EmergencyDeptDH', 'TwiningDH'],
#  ['KCH.EmergencyDeptDH', 'Victoria.AlbertDH'],
#  ['KCH.EmergencyDeptDH', 'Victoria.AlbertHDUDH'],
#  ['KCH.EmergencyDeptDH', 'WaddingtonDH'],
#  ['KatherineMonkDH', 'AnnieZunzDH'],
#  ['KatherineMonkDH', 'ByronDH'],
#  ['KatherineMonkDH', 'CheereDH'],
#  ['KatherineMonkDH', 'ChristineBrownCriticalCareDH'],
#  ['KatherineMonkDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['KatherineMonkDH', 'CoptcoatDH'],
#  ['KatherineMonkDH', 'CottonDH'],
#  ['KatherineMonkDH', 'DavidMarsdenDH'],
#  ['KatherineMonkDH', 'DavidsonDH'],
#  ['KatherineMonkDH', 'DawsonDH'],
#  ['KatherineMonkDH', 'DerekMitchellUnitDH'],
#  ['KatherineMonkDH', 'DonneDH'],
#  ['KatherineMonkDH', 'ElfandLibraDH'],
#  ['KatherineMonkDH', 'ExitHospitalDH'],
#  ['KatherineMonkDH', 'FiskDH'],
#  ['KatherineMonkDH', 'FrankCookseyOrpington'],
#  ['KatherineMonkDH', 'GuthrieDH'],
#  ['KatherineMonkDH', 'HowardDH'],
#  ['KatherineMonkDH', 'KCH.EmergencyDeptDH'],
#  ['KatherineMonkDH', 'KinnierWilsonDH'],
#  ['KatherineMonkDH', 'KinnierWilsonHDUDH'],
#  ['KatherineMonkDH', 'ListerDH'],
#  ['KatherineMonkDH', 'LiverICUDH'],
#  ['KatherineMonkDH', 'LonsdaleDH'],
#  ['KatherineMonkDH', 'MarjorieWarrenDH'],
#  ['KatherineMonkDH', 'MaryRayDH'],
#  ['KatherineMonkDH', 'MatthewWhitingDH'],
#  ['KatherineMonkDH', 'MedicalCriticalCareUnitDH'],
#  ['KatherineMonkDH', 'MedihomeDH'],
#  ['KatherineMonkDH', 'MurrayFalconerDH'],
#  ['KatherineMonkDH', 'OliverDH'],
#  ['KatherineMonkDH', 'RDLawrenceDH'],
#  ['KatherineMonkDH', 'SamOramDH'],
#  ['KatherineMonkDH', 'SurgicalCriticalCareUnitDH'],
#  ['KatherineMonkDH', 'SurgicalWard5PRUH'],
#  ['KatherineMonkDH', 'TheFriendsStrokeUnitDH'],
#  ['KatherineMonkDH', 'ToddDH'],
#  ['KatherineMonkDH', 'TrundleDH'],
#  ['KatherineMonkDH', 'TwiningDH'],
#  ['KatherineMonkDH', 'Victoria.AlbertDH'],
#  ['KinnierWilsonDH', 'AnnieZunzDH'],
#  ['KinnierWilsonDH', 'ByronDH'],
#  ['KinnierWilsonDH', 'ChristineBrownCriticalCareDH'],
#  ['KinnierWilsonDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['KinnierWilsonDH', 'CottonDH'],
#  ['KinnierWilsonDH', 'DavidMarsdenDH'],
#  ['KinnierWilsonDH', 'DawsonDH'],
#  ['KinnierWilsonDH', 'DonneDH'],
#  ['KinnierWilsonDH', 'ExitHospitalDH'],
#  ['KinnierWilsonDH', 'FarnboroughWardPRUH'],
#  ['KinnierWilsonDH', 'FrankCookseyOrpington'],
#  ['KinnierWilsonDH', 'GuthrieDH'],
#  ['KinnierWilsonDH', 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH'],
#  ['KinnierWilsonDH', 'IntensiveCare.HighDepUnit.PRUH.PRUH'],
#  ['KinnierWilsonDH', 'KCH.EmergencyDeptDH'],
#  ['KinnierWilsonDH', 'KatherineMonkDH'],
#  ['KinnierWilsonDH', 'KinnierWilsonHDUDH'],
#  ['KinnierWilsonDH', 'ListerDH'],
#  ['KinnierWilsonDH', 'LiverICUDH'],
#  ['KinnierWilsonDH', 'LonsdaleDH'],
#  ['KinnierWilsonDH', 'MarjorieWarrenDH'],
#  ['KinnierWilsonDH', 'MatthewWhitingDH'],
#  ['KinnierWilsonDH', 'MedicalCriticalCareUnitDH'],
#  ['KinnierWilsonDH', 'MedicalWard3PRUH'],
#  ['KinnierWilsonDH', 'MedihomeDH'],
#  ['KinnierWilsonDH', 'MurrayFalconerDH'],
#  ['KinnierWilsonDH', 'OliverDH'],
#  ['KinnierWilsonDH', 'Ontario.ORP.Orpington'],
#  ['KinnierWilsonDH', 'SurgicalCriticalCareUnitDH'],
#  ['KinnierWilsonDH', 'TheFriendsStrokeUnitDH'],
#  ['KinnierWilsonDH', 'ToddDH'],
#  ['KinnierWilsonDH', 'TrundleDH'],
#  ['KinnierWilsonDH', 'Victoria.AlbertHDUDH'],
#  ['KinnierWilsonDH', 'WaddingtonDH'],
#  ['KinnierWilsonHDUDH', 'ChristineBrownCriticalCareDH'],
#  ['KinnierWilsonHDUDH', 'DavidMarsdenDH'],
#  ['KinnierWilsonHDUDH', 'ExitHospitalDH'],
#  ['KinnierWilsonHDUDH', 'GuthrieDH'],
#  ['KinnierWilsonHDUDH', 'KatherineMonkDH'],
#  ['KinnierWilsonHDUDH', 'KinnierWilsonDH'],
#  ['KinnierWilsonHDUDH', 'MarjorieWarrenDH'],
#  ['KinnierWilsonHDUDH', 'MaryRayDH'],
#  ['KinnierWilsonHDUDH', 'MedicalCriticalCareUnitDH'],
#  ['KinnierWilsonHDUDH', 'MurrayFalconerDH'],
#  ['KinnierWilsonHDUDH', 'Ontario.ORP.Orpington'],
#  ['KinnierWilsonHDUDH', 'SurgicalCriticalCareUnitDH'],
#  ['KinnierWilsonHDUDH', 'TheFriendsStrokeUnitDH'],
#  ['KinnierWilsonHDUDH', 'TwiningDH'],
#  ['ListerDH', 'AnnieZunzDH'],
#  ['ListerDH', 'ByronDH'],
#  ['ListerDH', 'CheereDH'],
#  ['ListerDH', 'ChristineBrownCriticalCareDH'],
#  ['ListerDH', 'ClinicalDecisionUnit.A.E..DHDH'],
#  ['ListerDH', 'CoptcoatDH'],
#  ['ListerDH', 'CottonDH'],
#  ['ListerDH', 'DavidsonDH'],
#  ['ListerDH', 'DawsonDH'],
#  ['ListerDH', 'DonneDH'],
#  ['ListerDH', 'ElfandLibraDH'],
#  ...]

# %%
wholeNetwork = nx.MultiDiGraph()
wholeNetwork.add_nodes_from(allTransfers)
wholeNetwork.add_edges_from(listOfEdges)
pos = nx.kamada_kawai_layout(wholeNetwork)
nx.draw(wholeNetwork,pos=pos, with_labels=True, font_size=6,font_color='red',node_size = 25, width = 0.25, edge_color = 'grey',arrowsize=5)

#plt.rcParams['figure.figsize'] = [10, 5]
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #  Degree distribution

# %%
#print(type(list(wholeNetwork.in_degree())[0]))
In = list(wholeNetwork.in_degree())
listOfInDegrees = [x[1] for x in In]

listOfInDegreesNames = [x[0] for x in In]

print(In)

print(listOfInDegreesNames[listOfInDegrees.index(max(listOfInDegrees))])


#print(listOfInDegrees)
plt.hist(listOfInDegrees, bins=100)
plt.show()
# Out:
# [('AcuteMedicalUnit.EAUPRUH', 27), ('AcuteSurgicalUnitDH', 1), ('AdultCysticFibrosisUnitDH', 2), ('AnnieZunzDH', 33), ('Boddington.ORP.Orpington', 8), ('BrunelAdmissionsLoungeDH', 2), ('ByronDH', 31), ('ChartwellUnitPRUH', 22), ('CheereDH', 31), ('ChristineBrownCriticalCareDH', 43), ('ClinicalDecisionUnit.A.E..DHDH', 20), ('ClinicalDecisionUnit.PRUHPRUH', 18), ('CoptcoatDH', 30), ('CoronaryCareUnit.PRUH.PRUH', 30), ('CoronaryCareUnit.SamOram.DH', 26), ('CottonDH', 46), ('DavidMarsdenDH', 44), ('DavidsonDH', 31), ('DawsonDH', 40), ('DerekMitchellUnitDH', 29), ('DischargeLoungePRUH', 27), ('DonneDH', 34), ('ElfandLibraDH', 33), ('FarnboroughDayWardPRUH', 5), ('FarnboroughWardPRUH', 33), ('Fisk.CheereHDUDH', 14), ('FiskDH', 50), ('FrankCookseyOrpington', 12), ('GuthrieDH', 39), ('HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 32), ('HowardDH', 28), ('IntensiveCare.HighDepUnit.PRUH.PRUH', 29), ('KCH.EmergencyDeptDH', 30), ('KatherineMonkDH', 38), ('KinnierWilsonDH', 31), ('KinnierWilsonHDUDH', 23), ('ListerDH', 38), ('LiverICUDH', 40), ('LonsdaleDH', 31), ('MarjorieWarrenDH', 30), ('MaryRayDH', 36), ('MatthewWhitingDH', 37), ('MedicalCriticalCareUnitDH', 46), ('MedicalWard1PRUH', 27), ('MedicalWard2PRUH', 24), ('MedicalWard3PRUH', 29), ('MedicalWard4PRUH', 24), ('MedicalWard6PRUH', 26), ('MedicalWard7PRUH', 23), ('MedicalWard8PRUH', 25), ('MedicalWard9PRUH', 27), ('MedihomeDH', 27), ('MurrayFalconerDH', 26), ('OliverDH', 37), ('Ontario.ORP.Orpington', 28), ('PRUH.EmergencyDeptPRUH', 3), ('PlannedInvestigationUnitPRUH', 26), ('Quebec.ORP.Orpington', 3), ('RDLawrenceDH', 32), ('RecoveryWard1PRUH', 16), ('SamOramDH', 32), ('StrokeUnit.PRUH.PRUH', 21), ('SurgicalCriticalCareUnitDH', 40), ('SurgicalWard1.Darwin1.PRUH', 27), ('SurgicalWard2.Darwin2.PRUH', 24), ('SurgicalWard3.SAU.PRUH', 26), ('SurgicalWard4PRUH', 25), ('SurgicalWard5PRUH', 29), ('SurgicalWard6PRUH', 29), ('SurgicalWard7.Ortho.PRUH', 25), ('TheFriendsStrokeUnitDH', 33), ('ToddDH', 29), ('TrundleDH', 23), ('TwiningDH', 40), ('Victoria.AlbertDH', 31), ('Victoria.AlbertHDUDH', 28), ('WaddingtonDH', 22), ('ExitHospitalDH', 45), ('ExitHospitalOrpington', 4), ('ExitHospitalPRUH', 27)]
# FiskDH

# %%
#print(type(list(wholeNetwork.out_degree())[0]))
Out = list(wholeNetwork.out_degree())

#print(L)
listOfOutDegrees = [x[1] for x in Out]
listOfOutDegreesNames = [x[0] for x in Out]

print(Out, listOfOutDegrees[0], listOfOutDegreesNames[0])

print(listOfOutDegreesNames[listOfOutDegrees.index(max(listOfOutDegrees))])
print(listOfOutDegrees.index(max(listOfOutDegrees)))
plt.hist(listOfOutDegrees,bins=464)
plt.show()
# Out:
# [('AcuteMedicalUnit.EAUPRUH', 46), ('AcuteSurgicalUnitDH', 1), ('AdultCysticFibrosisUnitDH', 6), ('AnnieZunzDH', 42), ('Boddington.ORP.Orpington', 13), ('BrunelAdmissionsLoungeDH', 2), ('ByronDH', 28), ('ChartwellUnitPRUH', 26), ('CheereDH', 37), ('ChristineBrownCriticalCareDH', 43), ('ClinicalDecisionUnit.A.E..DHDH', 50), ('ClinicalDecisionUnit.PRUHPRUH', 40), ('CoptcoatDH', 21), ('CoronaryCareUnit.PRUH.PRUH', 37), ('CoronaryCareUnit.SamOram.DH', 17), ('CottonDH', 40), ('DavidMarsdenDH', 41), ('DavidsonDH', 33), ('DawsonDH', 28), ('DerekMitchellUnitDH', 19), ('DischargeLoungePRUH', 14), ('DonneDH', 18), ('ElfandLibraDH', 31), ('FarnboroughDayWardPRUH', 5), ('FarnboroughWardPRUH', 34), ('Fisk.CheereHDUDH', 7), ('FiskDH', 37), ('FrankCookseyOrpington', 8), ('GuthrieDH', 27), ('HASU.HyperAcuteStrokeUnit.PRUH.PRUH', 33), ('HowardDH', 26), ('IntensiveCare.HighDepUnit.PRUH.PRUH', 29), ('KCH.EmergencyDeptDH', 62), ('KatherineMonkDH', 40), ('KinnierWilsonDH', 34), ('KinnierWilsonHDUDH', 14), ('ListerDH', 38), ('LiverICUDH', 32), ('LonsdaleDH', 30), ('MarjorieWarrenDH', 19), ('MaryRayDH', 38), ('MatthewWhitingDH', 41), ('MedicalCriticalCareUnitDH', 39), ('MedicalWard1PRUH', 32), ('MedicalWard2PRUH', 29), ('MedicalWard3PRUH', 33), ('MedicalWard4PRUH', 25), ('MedicalWard6PRUH', 35), ('MedicalWard7PRUH', 27), ('MedicalWard8PRUH', 35), ('MedicalWard9PRUH', 47), ('MedihomeDH', 6), ('MurrayFalconerDH', 33), ('OliverDH', 43), ('Ontario.ORP.Orpington', 10), ('PRUH.EmergencyDeptPRUH', 32), ('PlannedInvestigationUnitPRUH', 26), ('Quebec.ORP.Orpington', 4), ('RDLawrenceDH', 42), ('RecoveryWard1PRUH', 15), ('SamOramDH', 32), ('StrokeUnit.PRUH.PRUH', 25), ('SurgicalCriticalCareUnitDH', 37), ('SurgicalWard1.Darwin1.PRUH', 20), ('SurgicalWard2.Darwin2.PRUH', 15), ('SurgicalWard3.SAU.PRUH', 35), ('SurgicalWard4PRUH', 36), ('SurgicalWard5PRUH', 36), ('SurgicalWard6PRUH', 30), ('SurgicalWard7.Ortho.PRUH', 33), ('TheFriendsStrokeUnitDH', 39), ('ToddDH', 28), ('TrundleDH', 23), ('TwiningDH', 39), ('Victoria.AlbertDH', 31), ('Victoria.AlbertHDUDH', 22), ('WaddingtonDH', 12), ('ExitHospitalDH', 0), ('ExitHospitalOrpington', 0), ('ExitHospitalPRUH', 0)] 46 AcuteMedicalUnit.EAUPRUH
# KCH.EmergencyDeptDH
# 32

# %%
#print(allTransfers)
nodeMetrics = pd.DataFrame({'Node':listOfInDegreesNames})
nodeMetrics['InDegree'] = listOfInDegrees
nodeMetrics['OutDegree'] = listOfOutDegrees

print(nodeMetrics[nodeMetrics['Node'] == 'KCH.EmergencyDeptDH'])

nodeMetrics.loc[nodeMetrics['InDegree'].idxmax()]
# Out:
#                    Node  InDegree  OutDegree
# 32  KCH.EmergencyDeptDH        30         62
# Node         FiskDH
# InDegree         50
# OutDegree        37
# Name: 26, dtype: object

# %%
allData[allData['FullSourceName'] =='KCH.EmergencyDeptDH'].Transfer.nunique()
# Out:
# 62

# %%
allTransfers
# Out:
# ['AcuteMedicalUnit.EAUPRUH',
#  'AcuteSurgicalUnitDH',
#  'AdultCysticFibrosisUnitDH',
#  'AnnieZunzDH',
#  'Boddington.ORP.Orpington',
#  'BrunelAdmissionsLoungeDH',
#  'ByronDH',
#  'ChartwellUnitPRUH',
#  'CheereDH',
#  'ChristineBrownCriticalCareDH',
#  'ClinicalDecisionUnit.A.E..DHDH',
#  'ClinicalDecisionUnit.PRUHPRUH',
#  'CoptcoatDH',
#  'CoronaryCareUnit.PRUH.PRUH',
#  'CoronaryCareUnit.SamOram.DH',
#  'CottonDH',
#  'DavidMarsdenDH',
#  'DavidsonDH',
#  'DawsonDH',
#  'DerekMitchellUnitDH',
#  'DischargeLoungePRUH',
#  'DonneDH',
#  'ElfandLibraDH',
#  'FarnboroughDayWardPRUH',
#  'FarnboroughWardPRUH',
#  'Fisk.CheereHDUDH',
#  'FiskDH',
#  'FrankCookseyOrpington',
#  'GuthrieDH',
#  'HASU.HyperAcuteStrokeUnit.PRUH.PRUH',
#  'HowardDH',
#  'IntensiveCare.HighDepUnit.PRUH.PRUH',
#  'KCH.EmergencyDeptDH',
#  'KatherineMonkDH',
#  'KinnierWilsonDH',
#  'KinnierWilsonHDUDH',
#  'ListerDH',
#  'LiverICUDH',
#  'LonsdaleDH',
#  'MarjorieWarrenDH',
#  'MaryRayDH',
#  'MatthewWhitingDH',
#  'MedicalCriticalCareUnitDH',
#  'MedicalWard1PRUH',
#  'MedicalWard2PRUH',
#  'MedicalWard3PRUH',
#  'MedicalWard4PRUH',
#  'MedicalWard6PRUH',
#  'MedicalWard7PRUH',
#  'MedicalWard8PRUH',
#  'MedicalWard9PRUH',
#  'MedihomeDH',
#  'MurrayFalconerDH',
#  'OliverDH',
#  'Ontario.ORP.Orpington',
#  'PRUH.EmergencyDeptPRUH',
#  'PlannedInvestigationUnitPRUH',
#  'Quebec.ORP.Orpington',
#  'RDLawrenceDH',
#  'RecoveryWard1PRUH',
#  'SamOramDH',
#  'StrokeUnit.PRUH.PRUH',
#  'SurgicalCriticalCareUnitDH',
#  'SurgicalWard1.Darwin1.PRUH',
#  'SurgicalWard2.Darwin2.PRUH',
#  'SurgicalWard3.SAU.PRUH',
#  'SurgicalWard4PRUH',
#  'SurgicalWard5PRUH',
#  'SurgicalWard6PRUH',
#  'SurgicalWard7.Ortho.PRUH',
#  'TheFriendsStrokeUnitDH',
#  'ToddDH',
#  'TrundleDH',
#  'TwiningDH',
#  'Victoria.AlbertDH',
#  'Victoria.AlbertHDUDH',
#  'WaddingtonDH',
#  'ExitHospitalDH',
#  'ExitHospitalOrpington',
#  'ExitHospitalPRUH']

# %% [markdown]
# # Centrality

# %%
eigenvectorCentrality = nx.eigenvector_centrality_numpy(wholeNetwork)
print(eigenvectorCentrality)
listOfEigCentrality = []
#for i in listOfInDegreesNames:
[x[1] for x in eigenvectorCentrality]
nodeMetrics['Eigenvector Centrality'] = listOfEigCentrality

nodeMetrics.head()
# Out:
# {'AcuteMedicalUnit.EAUPRUH': 0.04008109123121423, 'AcuteSurgicalUnitDH': 0.0020900407922411542, 'AdultCysticFibrosisUnitDH': 0.006100867434634975, 'AnnieZunzDH': 0.15815330647598966, 'Boddington.ORP.Orpington': 0.010863819098968644, 'BrunelAdmissionsLoungeDH': 0.011193683439245167, 'ByronDH': 0.1484726278786657, 'ChartwellUnitPRUH': 0.037581631570343575, 'CheereDH': 0.1317664958793836, 'ChristineBrownCriticalCareDH': 0.18776548823800407, 'ClinicalDecisionUnit.A.E..DHDH': 0.0766870104861375, 'ClinicalDecisionUnit.PRUHPRUH': 0.02690204245344902, 'CoptcoatDH': 0.1410657731692672, 'CoronaryCareUnit.PRUH.PRUH': 0.05468243118673537, 'CoronaryCareUnit.SamOram.DH': 0.10959834610631816, 'CottonDH': 0.19127800535115194, 'DavidMarsdenDH': 0.1545269933760645, 'DavidsonDH': 0.14983378656706955, 'DawsonDH': 0.17072187672572545, 'DerekMitchellUnitDH': 0.13790273967920616, 'DischargeLoungePRUH': 0.04018554510523791, 'DonneDH': 0.15409047446444213, 'ElfandLibraDH': 0.15343603519433632, 'FarnboroughDayWardPRUH': 0.007387310328905022, 'FarnboroughWardPRUH': 0.05924881098634468, 'Fisk.CheereHDUDH': 0.05555015663090277, 'FiskDH': 0.18854872558568694, 'FrankCookseyOrpington': 0.050289657762111, 'GuthrieDH': 0.16970265772783633, 'HASU.HyperAcuteStrokeUnit.PRUH.PRUH': 0.06434537052636928, 'HowardDH': 0.13365814799341966, 'IntensiveCare.HighDepUnit.PRUH.PRUH': 0.05895706590438695, 'KCH.EmergencyDeptDH': 0.06350054045996341, 'KatherineMonkDH': 0.165937691577121, 'KinnierWilsonDH': 0.11494432158765563, 'KinnierWilsonHDUDH': 0.100302566445398, 'ListerDH': 0.16577552729147374, 'LiverICUDH': 0.17542113309515053, 'LonsdaleDH': 0.13946077385676944, 'MarjorieWarrenDH': 0.14525206528077833, 'MaryRayDH': 0.1590480274433597, 'MatthewWhitingDH': 0.16140625415357077, 'MedicalCriticalCareUnitDH': 0.19375867121839796, 'MedicalWard1PRUH': 0.045888646084080956, 'MedicalWard2PRUH': 0.04186118256842624, 'MedicalWard3PRUH': 0.06054893072382351, 'MedicalWard4PRUH': 0.03818657876135789, 'MedicalWard6PRUH': 0.043858733299002986, 'MedicalWard7PRUH': 0.03416598598349618, 'MedicalWard8PRUH': 0.05112279460815545, 'MedicalWard9PRUH': 0.043824520094185325, 'MedihomeDH': 0.12185870267638502, 'MurrayFalconerDH': 0.12024847775227854, 'OliverDH': 0.1691972724083142, 'Ontario.ORP.Orpington': 0.07470391816232948, 'PRUH.EmergencyDeptPRUH': 0.0036505849423943493, 'PlannedInvestigationUnitPRUH': 0.035160709900443406, 'Quebec.ORP.Orpington': 0.006538911719907298, 'RDLawrenceDH': 0.1439797584705571, 'RecoveryWard1PRUH': 0.021032910149755238, 'SamOramDH': 0.13974787648462828, 'StrokeUnit.PRUH.PRUH': 0.04264896687058288, 'SurgicalCriticalCareUnitDH': 0.18272199532530153, 'SurgicalWard1.Darwin1.PRUH': 0.04832071608442304, 'SurgicalWard2.Darwin2.PRUH': 0.038307463811526825, 'SurgicalWard3.SAU.PRUH': 0.04076420360558525, 'SurgicalWard4PRUH': 0.04018711803583189, 'SurgicalWard5PRUH': 0.04589534205808224, 'SurgicalWard6PRUH': 0.05170547832452766, 'SurgicalWard7.Ortho.PRUH': 0.04240728584604181, 'TheFriendsStrokeUnitDH': 0.1401571182556008, 'ToddDH': 0.13084808833035483, 'TrundleDH': 0.10995585412251344, 'TwiningDH': 0.17089415105506142, 'Victoria.AlbertDH': 0.13072157927688263, 'Victoria.AlbertHDUDH': 0.12509389579272795, 'WaddingtonDH': 0.10776208657967794, 'ExitHospitalDH': 0.19781615719173995, 'ExitHospitalOrpington': 0.004686796169013022, 'ExitHospitalPRUH': 0.03802389929695841}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9f82d6804720> in <module>
#       4 #for i in listOfInDegreesNames:
#       5 [x[1] for x in eigenvectorCentrality]
# ----> 6 nodeMetrics['Eigenvector Centrality'] = listOfEigCentrality
#       7
#       8 nodeMetrics.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3562
#    3563         self._ensure_valid_index(value)
# -> 3564         value = self._sanitize_column(key, value)
#    3565         NDFrame._set_item(self, key, value)
#    3566
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3747
#    3748             # turn me into an ndarray
# -> 3749             value = sanitize_index(value, self.index, copy=False)
#    3750             if not isinstance(value, (np.ndarray, Index)):
#    3751                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# # Betweeness

# %%
betweennessCentrality = nx.betweenness_centrality(wholeNetwork,normalized=True)
